# %% [markdown]
# <a href="https://colab.research.google.com/github/Untick/InspectrumClinic_RS_gr2/blob/main/Borisov%20Vasily/Profpatolog_%2B_Hazard_Risk_%2B_ConfMatrix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - Импортируем основные библиотеки
# - Загружаем список колонок датасета, которые мы предполагаем использовать для построния модели.
# - Список колонок хранится в файле эксель. Файл эксель - на Яндекс Диске.
# - Загружаем Датасет с Яндекс Клауда.

# %%
import pandas as pd
import numpy as np
import gdown
from sklearn.model_selection import train_test_split
import requests
from urllib.parse import urlencode
import seaborn as sns
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay


# читаем список нужных нам полей с ЯД (файл эксель)
base_url = 'https://cloud-api.yandex.net/v1/disk/public/resources/download?'
public_key = 'https://disk.yandex.ru/i/QWJez3NW1JGGcg'
final_url = base_url + urlencode(dict(public_key=public_key))
response = requests.get(final_url)
download_url = response.json()['href']
download_response = requests.get(download_url)
df_polei = pd.read_excel(download_url)

gdown.download('https://storage.yandexcloud.net/terratraineeship/23_InspectrumClinic_RS/datasets/датасет%20профпатолог%20часть.xlsx', None, quiet=True)
data = pd.read_excel('E:\ProfPat\датасет%20профпатолог%20часть.xlsx')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 21
#      18 df_polei = pd.read_excel(download_url)
#      20 gdown.download('https://storage.yandexcloud.net/terratraineeship/23_InspectrumClinic_RS/datasets/датасет%20профпатолог%20часть.xlsx', None, quiet=True)
# ---> 21 data = pd.read_excel('E:\ProfPat\датасет%20профпатолог%20часть.xlsx')
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:486, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     480     raise ValueError(
#     481         "Engine should not be specified when passing "
#     482         "an ExcelFile - ExcelFile already has the engine set"
#     483     )
#     485 try:
# --> 486     data = io.parse(
#     487         sheet_name=sheet_name,
#     488         header=header,
#     489         names=names,
#     490         index_col=index_col,
#     491         usecols=usecols,
#     492         dtype=dtype,
#     493         converters=converters,
#     494         true_values=true_values,
#     495         false_values=false_values,
#     496         skiprows=skiprows,
#     497         nrows=nrows,
#     498         na_values=na_values,
#     499         keep_default_na=keep_default_na,
#     500         na_filter=na_filter,
#     501         verbose=verbose,
#     502         parse_dates=parse_dates,
#     503         date_parser=date_parser,
#     504         date_format=date_format,
#     505         thousands=thousands,
#     506         decimal=decimal,
#     507         comment=comment,
#     508         skipfooter=skipfooter,
#     509         dtype_backend=dtype_backend,
#     510     )
#     511 finally:
#     512     # make sure to close opened file handles
#     513     if should_close:
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:1551, in ExcelFile.parse(self, sheet_name, header, names, index_col, usecols, converters, true_values, false_values, skiprows, nrows, na_values, parse_dates, date_parser, date_format, thousands, comment, skipfooter, dtype_backend, **kwds)
#    1518 def parse(
#    1519     self,
#    1520     sheet_name: str | int | list[int] | list[str] | None = 0,
#    (...)
#    1538     **kwds,
#    1539 ) -> DataFrame | dict[str, DataFrame] | dict[int, DataFrame]:
#    1540     """
#    1541     Parse specified sheet(s) into a DataFrame.
#    1542
#    (...)
#    1549         DataFrame from the passed in Excel file.
#    1550     """
# -> 1551     return self._reader.parse(
#    1552         sheet_name=sheet_name,
#    1553         header=header,
#    1554         names=names,
#    1555         index_col=index_col,
#    1556         usecols=usecols,
#    1557         converters=converters,
#    1558         true_values=true_values,
#    1559         false_values=false_values,
#    1560         skiprows=skiprows,
#    1561         nrows=nrows,
#    1562         na_values=na_values,
#    1563         parse_dates=parse_dates,
#    1564         date_parser=date_parser,
#    1565         date_format=date_format,
#    1566         thousands=thousands,
#    1567         comment=comment,
#    1568         skipfooter=skipfooter,
#    1569         dtype_backend=dtype_backend,
#    1570         **kwds,
#    1571     )
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:751, in BaseExcelReader.parse(self, sheet_name, header, names, index_col, usecols, dtype, true_values, false_values, skiprows, nrows, na_values, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, dtype_backend, **kwds)
#     748     sheet = self.get_sheet_by_index(asheetname)
#     750 file_rows_needed = self._calc_rows(header, index_col, skiprows, nrows)
# --> 751 data = self.get_sheet_data(sheet, file_rows_needed)
#     752 if hasattr(sheet, "close"):
#     753     # pyxlsb opens two TemporaryFiles
#     754     sheet.close()
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_openpyxl.py:602, in OpenpyxlReader.get_sheet_data(self, sheet, file_rows_needed)
#     600 data: list[list[Scalar]] = []
#     601 last_row_with_data = -1
# --> 602 for row_number, row in enumerate(sheet.rows):
#     603     converted_row = [self._convert_cell(cell) for cell in row]
#     604     while converted_row and converted_row[-1] == "":
#     605         # trim trailing empty elements
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_read_only.py:81, in ReadOnlyWorksheet._cells_by_row(self, min_col, min_row, max_col, max_row, values_only)
#      77 src = self._get_source()
#      78 parser = WorkSheetParser(src, self._shared_strings,
#      79                          data_only=self.parent.data_only, epoch=self.parent.epoch,
#      80                          date_formats=self.parent._date_formats)
# ---> 81 for idx, row in parser.parse():
#      82     if max_row is not None and idx > max_row:
#      83         break
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:167, in WorkSheetParser.parse(self)
#     165     element.clear()
#     166 elif tag_name == ROW_TAG:
# --> 167     row = self.parse_row(element)
#     168     element.clear()
#     169     yield row
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:303, in WorkSheetParser.parse_row(self, row)
#     299 if keys - {'r', 'spans'}:
#     300     # don't create dimension objects unless they have relevant information
#     301     self.row_dimensions[str(self.row_counter)] = attrs
# --> 303 cells = [self.parse_cell(el) for el in row]
#     304 return self.row_counter, cells
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:303, in <listcomp>(.0)
#     299 if keys - {'r', 'spans'}:
#     300     # don't create dimension objects unless they have relevant information
#     301     self.row_dimensions[str(self.row_counter)] = attrs
# --> 303 cells = [self.parse_cell(el) for el in row]
#     304 return self.row_counter, cells
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:191, in WorkSheetParser.parse_cell(self, element)
#     189 def parse_cell(self, element):
#     190     data_type = element.get('t', 'n')
# --> 191     coordinate = element.get('r')
#     192     style_id = element.get('s', 0)
#     193     if style_id:
#
# KeyboardInterrupt:

# %%
for (columnName, columnData) in data2.items():
  print(columnName + ' /// ' + str(columnData.nunique()))

# %% [markdown]
# - Выводим список колонок, у которых количество значений (nunique()) больше 1 и меньше 35
# - В модели это не используется. Только как заготовка для будущего анализа и добавления новых колонок в список анализируемых.

# %%
for (columnName, columnData) in data.items():
  if columnData.nunique()>1 and columnData.nunique()<35:
    print(columnName + ' /// ' + str(columnData.nunique()))

# %% [markdown]
# - Приводим 6 возможных значений категории годности к 3 (в соответствии с ТЗ).
# - Например если в датасете категория годности = "ГоденСКоррекциейЗрения", то мы заменяем это значение на "ОграниченноГоден"

# %%
data=data.replace('ГоденСКоррекциейЗрения','ОграниченноГоден')
data=data.replace('ГоденБезРаботНаВысотах','ОграниченноГоден')
data=data.replace('НуждаетсяВДообследованииИЛечении','ВременноНегоден')

# %%
data['ЗаключениеМК'].value_counts()#[['ОграниченноГоден']].sum()
# Out:
# ЗаключениеМК
# Годен                  1434
# ОграниченноГоден        126
# ВременноНегоден          11
# Газоспасатель             2
# машинист бульдозера       1
#  Газоспасатель            1
# Name: count, dtype: int64

# %% [markdown]
# "Размножаем" минорные классы (классы с метками "ВременноНегоден" и "ОграниченноГоден")

# %%
for i in range(4):
    data = pd.concat([data,data.loc[data['ЗаключениеМК']. isin(['ВременноНегоден', 'ОграниченноГоден'])]])

# %%
data.shape
# Out:
# (4037, 4587)

# %% [markdown]
# Копируем наш датасет в data500 (на всякий случай оригинальный датасет оставляем без изменений)
# Чистим датафрейм data500
#  - удаляя лишние колонки (напомню список нужных колонок храним в эксель файле) и
#  - строки, у которых неверно заполнена колонка ЗаключениеМК

# %%
data500  = data.copy()
nmp=df_polei['POLE'].tolist()
print(nmp)

for (columnName, columnData) in data500.items():
  if (str(columnName) in nmp)==False:
    data500.pop(columnName)

data500 = data500[data500.ЗаключениеМК.isin(['Годен', 'ВременноНегоден', 'ОграниченноГоден']) == True ]
# Out:
# ['КлиентПолПредставление', 'Профессия', 'ЗаключениеМК', 'ВредныеФакторы', 'Рентгенология1_Заключение_ЗначениеПредставление', 'ПсихиатрияНаркология1_МКБ101', 'ПсихиатрияНаркология1_ГоденНегоден_ЗначениеПредставление', 'Офтальмология1_МКБ101', 'Офтальмология1_ГоденНегоден_ЗначениеПредставление', 'Оториноларингология1_МКБ101', 'Оториноларингология1_ГоденНегоден_ЗначениеПредставление', 'ХирургНеИсп1_МКБ101', 'ХирургНеИсп1_ГоденНегоден_ЗначениеПредставление', 'Гинекология1_МКБ101', 'Гинекология1_ГоденНегоден_ЗначениеПредставление', 'Стоматология1_МКБ101', 'Стоматология1_ГоденНегоден_ЗначениеПредставление', 'Терапия1_ГоденНегоден_ЗначениеПредставление', 'Дерматовенерология1_МКБ101', 'Дерматовенерология1_ГоденНегоден_ЗначениеПредставление', 'Рентгенология1_МКБ101', 'Рентгенология1_ПрофнепригодностьВременная1', 'Неврология1_МКБ101', 'Неврология1_ПрофнепригодностьВременная1', 'Неврология1_ГоденНегоден_ЗначениеПредставление', 'Терапия1_МКБ101', 'Хирургия1_МКБ101', 'Хирургия1_ГоденНегоден_ЗначениеПредставление', 'Хирургия2_ГоденНегоден_ЗначениеПредставление', 'Офтальмология1_МКБ102', 'Терапия2_МКБ101', 'Терапия2_ГоденНегоден_ЗначениеПредставление', 'Неврология2_МКБ101', 'Неврология2_ГоденНегоден_ЗначениеПредставление', 'ЛабораторныеИсследования1_МКБ101', 'ЭКГНеИсп1_МКБ101', 'Гинекология1_ГоденНегоденДополнение_ЗначениеПредставление', 'УЗИДиагностика1_МКБ101', 'УЗИДиагностика2_МКБ101', 'ПсихиатрияНаркология2_МКБ101', 'ПсихиатрияНаркология2_ГоденНегоден_ЗначениеПредставление', 'Терапия1_МКБ102', 'ЛабораторныеИсследования2_МКБ101', 'Терапия1_МКБ103', 'Неврология1_ГоденНегоденДополнение_ЗначениеПредставление', 'Психиатрия1_МКБ101', 'Психиатрия1_ГоденНегоден_ЗначениеПредставление', 'Гинекология1_МКБ102', 'Рентгенология2_МКБ101', 'Гинекология2_МКБ101', 'Гинекология2_ГоденНегоден_ЗначениеПредставление', 'Хирургия2_МКБ101', 'ПроцедурнаяМедсестра1_МКБ101', 'ФункциональнаяДиагностика1_МКБ101', 'УЗИДиагностика1_МКБ102', 'Стоматология2_МКБ101', 'Стоматология2_ГоденНегоден_ЗначениеПредставление', 'Неврология1_МКБ102', 'Оториноларингология2_МКБ101', 'Оториноларингология2_ГоденНегоден_ЗначениеПредставление', 'Дерматовенерология1_МКБ102', 'Дерматовенерология2_МКБ101', 'Дерматовенерология2_ГоденНегоден_ЗначениеПредставление', 'Дерматовенерология2_МКБ102', 'Хирургия1_МКБ102', 'Хирургия2_МКБ102', 'Офтальмология2_МКБ101', 'Офтальмология2_МКБ102', 'Офтальмология2_ГоденНегоден_ЗначениеПредставление', 'Неврология2_МКБ102', 'ПсихиатрияНаркология1_МКБ102', 'ПсихиатрияНаркология2_МКБ102', 'УЗИДиагностика2_МКБ102', 'Оториноларингология1_МКБ102', 'Оториноларингология2_МКБ102', 'Терапия2_МКБ102', 'Оториноларингология1_МКБ103', 'Оториноларингология1_МКБ104', 'Оториноларингология2_МКБ103', 'Оториноларингология2_МКБ104', 'Терапия3_МКБ101', 'Терапия3_МКБ102', 'Терапия3_ГоденНегоден_ЗначениеПредставление', 'Терапия4_МКБ101', 'Терапия4_МКБ102', 'Терапия4_ГоденНегоден_ЗначениеПредставление', 'Гинекология2_МКБ102', 'УЗИДиагностика1_МКБ103', 'УЗИДиагностика1_МКБ104', 'УЗИДиагностика2_МКБ103', 'УЗИДиагностика2_МКБ104', 'Стоматология1_МКБ102', 'Стоматология2_МКБ102', 'Терапия1_МКБ104', 'Терапия2_МКБ103', 'Терапия2_МКБ104', 'Офтальмология1_МКБ103', 'Офтальмология1_МКБ104', 'Офтальмология2_МКБ103', 'Офтальмология2_МКБ104', 'ЛабораторныеИсследования1_МКБ102', 'ЛабораторныеИсследования2_МКБ102', 'Неврология2_ГоденНегоденДополнение_ЗначениеПредставление', 'Хирургия3_МКБ101', 'Хирургия3_ГоденНегоден_ЗначениеПредставление', 'Гинекология3_МКБ101', 'Гинекология3_МКБ102', 'Гинекология3_ГоденНегоден_ЗначениеПредставление', 'Гинекология4_МКБ101', 'Гинекология4_МКБ102', 'Гинекология4_ГоденНегоден_ЗначениеПредставление', 'Офтальмология1_ГоденНегоденДополнение_ЗначениеПредставление', 'ТерапевтНеИсп1_ГоденНегоден_ЗначениеПредставление', 'ТерапевтНеИсп1_МКБ101', 'Эндоскопия1_МКБ101', 'ТерапевтНеИсп1_МКБ102', 'ХирургНеИсп1_МКБ102', 'ХирургНеИсп2_МКБ101', 'ХирургНеИсп2_МКБ102', 'ХирургНеИсп2_ГоденНегоден_ЗначениеПредставление', 'Психиатрия1_МКБ102', 'Психиатрия2_МКБ101', 'Психиатрия2_МКБ102', 'П ...

# %% [markdown]
# Формируем списки:
# - ListOfColumnNames - наименования колонок
# - ListOfColumnValues - значения колонок
# - ListOfColumnNames_Lists - значения колонки, в которой содержится список значений (пока это одна колонка - ВредныеФакторы)
# - В дальнейшем мы будем использовать эту информацию для токенизации данных нашего датасета

# %%
razdelitel = ","
columnsWithLists = ['ВредныеФакторы']
ListOfColumnNames = []
ListOfColumnValues = []
ListOfColumnNames_Lists = []
for (columnName, columnData) in data500.items():
  ListOfColumnNames.append(columnName)
  if columnName in columnsWithLists:
    ListOfColumnValues.append(list(set(razdelitel.join(data500[columnName].tolist()).splitlines()[0].split(','))))
  else:
    ListOfColumnValues.append(list(data500[columnName].dropna().unique().flatten()))

# %% [markdown]
# Приводим наш датасет к векторам

# %%
def get_vector(row, columnNumber):
  i = 0
  vector = []
  vectorLen = len(ListOfColumnValues[columnNumber])
  if vectorLen < 25:
    while i < vectorLen:
      if (ListOfColumnValues[columnNumber][i] == row[columnNumber]):
        Null_or_One = 1
      else:
        Null_or_One = 0
      vector = np.hstack([vector, Null_or_One])
      i+=1
  return vector


def get_vector_from_list(row, columnNumber):
  i = 0
  vector = []
  vectorLen = len(ListOfColumnValues[columnNumber])
  rowToList = ((row[columnNumber].split(',')))
  while i < vectorLen:
    if (ListOfColumnValues[columnNumber][i] in rowToList):
      Null_or_One = 1
    else:
      Null_or_One = 0
    vector = np.hstack([vector, Null_or_One])
    i+=1
  return vector


def extract_row_data(row):
  x1_data = []
  x2_data = []
  y_data = []
  for columnName in ListOfColumnNames:
    columnNumber = ListOfColumnNames.index(columnName)
    if columnName == 'ЗаключениеМК':
      y_data = np.hstack([y_data, get_vector(row, columnNumber)])
    elif columnName in columnsWithLists:
      x2_data = np.hstack([x2_data, get_vector_from_list(row, columnNumber)])
    else:
      x1_data = np.hstack([x1_data, get_vector(row, columnNumber)])
  return x1_data, x2_data, y_data



def construct_train_data(row_list):
    x1_data = []
    x2_data = []
    y_data = []
    for row in row_list:
      x1, x2, y = extract_row_data(row)
      x1_data.append(x1)
      x2_data.append(x2)
      y_data.append(y)
    return np.array(x1_data), np.array(x2_data), np.array(y_data)


x1_data500, x2_data500, y_data500 = construct_train_data(data500.values)

# %% [markdown]
# Импортируем модель FastText. Модель большая (> 7 Гб), поэтому делал все локально

# %%
import fasttext
ft = fasttext.load_model('E:\cc.ru.300.bin')

# %% [markdown]
# Преобразуем профессию сотрудника в вектор, используя fasttext

# %%
x3_data = []
for row in data500.values:
  wordVector = ft.get_word_vector(str(row[1]))
  x3_data.append(wordVector)
x3_data500 = np.array(x3_data)

# %%
# Разбиение наборов на общую и тестовую выборки
x1_all, x1_test, x2_all, x2_test, x3_all, x3_test, y_all, y_test = train_test_split(
                                                x1_data500,
                                                x2_data500,
                                                x3_data500,
                                                y_data500,
                                                test_size=0.1,
                                                shuffle=True,
                                                random_state = 6)

# Разбиение общей выборки на обучающую и проверочную
x1_train, x1_val, x2_train, x2_val, x3_train, x3_val, y_train, y_val = train_test_split(
                                                  x1_all,
                                                  x2_all,
                                                  x3_all,
                                                  y_all,
                                                  test_size=0.1,
                                                  shuffle=True,
                                                  random_state = 6)

# %% [markdown]
# Запускаем модель

# %%
from tensorflow import keras
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, concatenate, Input, CategoryEncoding, Normalization, Activation, Conv1D
from tensorflow.keras.optimizers import Adam, AdamW, RMSprop
from tensorflow.keras import utils
# from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image


# %matplotlib inline

# Разбиение наборов на общую и тестовую выборки
x1_all, x1_test, x2_all, x2_test, x3_all, x3_test, y_all, y_test = train_test_split(
                                                x1_data500,
                                                x2_data500,
                                                x3_data500,
                                                y_data500,
                                                test_size=0.1,
                                                shuffle=True,
                                                random_state = 6)

# Разбиение общей выборки на обучающую и проверочную
x1_train, x1_val, x2_train, x2_val, x3_train, x3_val, y_train, y_val = train_test_split(
                                                  x1_all,
                                                  x2_all,
                                                  x3_all,
                                                  y_all,
                                                  test_size=0.1,
                                                  shuffle=True,
                                                  random_state = 6)


input1 = Input((x1_train.shape[1],))
input2 = Input((x2_train.shape[1],))
input3 = Input((x3_train.shape[1],))

x1 = input1                               # Ветка 1
x1 = Normalization()(x1)
x1 = Dense(256, activation="relu")(x1)
x1 = Dropout(0.1)(x1)                   #ddfds удал
x1 = Activation('relu')(x1)
x1 = Dense(32, activation="relu")(x1)
x1 = Activation('relu')(x1)
x1 = Dense(3, activation="relu")(x1)

x2 = input2                               # Ветка 2
x2 = Dense(20, activation="relu")(x2)
# x2 = Dropout(0.15)(x2)
x2 = Dense(500, activation="relu")(x2)

x3 = input3                               # Ветка 3
x3 = Dense(50, activation="relu")(x3)
x3 = Dense(500, activation="relu")(x3)

x23 = concatenate([x2, x3])             # Объединение 3 веток
x23 = Dense(15, activation='relu')(x23) # Промежуточный слой
x = concatenate([x1, x23])              # Объединение 3 веток




x = Dense(15, activation='relu')(x)       # Промежуточный слой
x = Dropout(0.3)(x)
x = Dense(128, activation='relu')(x)
#x = keras.constraints.MinMaxNorm(min_value=0.0, max_value=1.0, rate=1.0, axis=0)(x)
x = Dense(3, activation='softmax')(x)      # Финальный регрессирующий нейрон

# В Model передаются входы и выход
model_final = Model((input1, input2, input3), x)

# model_final.compile(optimizer=Adam(learning_rate=1e-3), loss='categorical_crossentropy', metrics=['mae'])
model_final.compile(optimizer=Adam(learning_rate=1e-3), loss='categorical_crossentropy', metrics=['accuracy'])
history = model_final.fit([x1_train, x2_train, x3_train],
                           y_train,
                           batch_size=256,
                           epochs=150,
                           validation_split=0.15,
                           verbose=1)
# Out:
# Epoch 1/150
# 10/10 [==============================] - 8s 171ms/step - loss: 1.0489 - accuracy: 0.4858 - val_loss: 0.9665 - val_accuracy: 0.4921
# Epoch 2/150
# 10/10 [==============================] - 1s 110ms/step - loss: 0.8711 - accuracy: 0.5431 - val_loss: 0.8726 - val_accuracy: 0.4921
# Epoch 3/150
# 10/10 [==============================] - 1s 93ms/step - loss: 0.8088 - accuracy: 0.5591 - val_loss: 0.8131 - val_accuracy: 0.4921
# Epoch 4/150
# 10/10 [==============================] - 1s 94ms/step - loss: 0.7532 - accuracy: 0.5747 - val_loss: 0.7693 - val_accuracy: 0.4921
# Epoch 5/150
# 10/10 [==============================] - 1s 93ms/step - loss: 0.6956 - accuracy: 0.6020 - val_loss: 0.6825 - val_accuracy: 0.6644
# Epoch 6/150
# 10/10 [==============================] - 1s 94ms/step - loss: 0.6103 - accuracy: 0.7022 - val_loss: 0.5433 - val_accuracy: 0.7846
# Epoch 7/150
# 10/10 [==============================] - 1s 93ms/step - loss: 0.4922 - accuracy: 0.7944 - val_loss: 0.4284 - val_accuracy: 0.8345
# Epoch 8/150
# 10/10 [==============================] - 1s 94ms/step - loss: 0.3870 - accuracy: 0.8529 - val_loss: 0.3595 - val_accuracy: 0.8503
# Epoch 9/150
# 10/10 [==============================] - 1s 95ms/step - loss: 0.3179 - accuracy: 0.8741 - val_loss: 0.3114 - val_accuracy: 0.8798
# Epoch 10/150
# 10/10 [==============================] - 1s 96ms/step - loss: 0.2648 - accuracy: 0.8910 - val_loss: 0.2707 - val_accuracy: 0.8821
# Epoch 11/150
# 10/10 [==============================] - 1s 96ms/step - loss: 0.2245 - accuracy: 0.9014 - val_loss: 0.2645 - val_accuracy: 0.8844
# Epoch 12/150
# 10/10 [==============================] - 1s 95ms/step - loss: 0.2050 - accuracy: 0.9291 - val_loss: 0.2157 - val_accuracy: 0.9410
# Epoch 13/150
# 10/10 [==============================] - 1s 95ms/step - loss: 0.1694 - accuracy: 0.9455 - val_loss: 0.1939 - val_accuracy: 0.9456
# Epoch 14/150
# 10/10 [==============================] - 1s 96ms/step - loss: 0.1389 - accuracy: 0.9591 - val_loss: 0.1676 - val_accuracy: 0.9569
# Epoch 15/150
# 10/10 [==============================] - 1s 111ms/step - loss: 0.1283 - accuracy: 0.9591 - val_loss: 0.2040 - val_accuracy: 0.9433
# Epoch 16/150
# 10/10 [==============================] - 1s 97ms/step - loss: 0.1145 - accuracy: 0.9643 - val_loss: 0.1655 - val_accuracy: 0.9569
# Epoch 17/150
# 10/10 [==============================] - 1s 93ms/step - loss: 0.0979 - accuracy: 0.9719 - val_loss: 0.1765 - val_accuracy: 0.9569
# Epoch 18/150
# 10/10 [==============================] - 1s 94ms/step - loss: 0.0954 - accuracy: 0.9727 - val_loss: 0.1449 - val_accuracy: 0.9660
# Epoch 19/150
# 10/10 [==============================] - 1s 94ms/step - loss: 0.0864 - accuracy: 0.9756 - val_loss: 0.1366 - val_accuracy: 0.9660
# Epoch 20/150
# 10/10 [==============================] - 1s 98ms/step - loss: 0.0816 - accuracy: 0.9768 - val_loss: 0.1481 - val_accuracy: 0.9615
# Epoch 21/150
# 10/10 [==============================] - 1s 95ms/step - loss: 0.0725 - accuracy: 0.9796 - val_loss: 0.1474 - val_accuracy: 0.9660
# Epoch 22/150
# 10/10 [==============================] - 1s 95ms/step - loss: 0.0779 - accuracy: 0.9788 - val_loss: 0.1608 - val_accuracy: 0.9660
# Epoch 23/150
# 10/10 [==============================] - 1s 96ms/step - loss: 0.0760 - accuracy: 0.9792 - val_loss: 0.1390 - val_accuracy: 0.9683
# Epoch 24/150
# 10/10 [==============================] - 1s 132ms/step - loss: 0.0741 - accuracy: 0.9804 - val_loss: 0.1298 - val_accuracy: 0.9728
# Epoch 25/150
# 10/10 [==============================] - 1s 106ms/step - loss: 0.0635 - accuracy: 0.9824 - val_loss: 0.1320 - val_accuracy: 0.9728
# Epoch 26/150
# 10/10 [==============================] - 1s 101ms/step - loss: 0.0635 - accuracy: 0.9812 - val_loss: 0.1458 - val_accuracy: 0.9705
# Epoch 27/150
# 10/10 [==============================] - 1s 123ms/step - loss: 0.0545 - accuracy: 0.9868 - val_loss: 0.1524 - val_accuracy: 0.9705
# Epoch 28/150
# 10/10 [==============================] - 1s 105ms/step - loss: 0.0540 - accuracy: 0.9860 - val_loss: 0.1473 - val_accuracy: 0.9728
# Epoch 29/150
# 10/10 [==============================] - 1s 103ms/step - loss: 0.0432 - accuracy: 0.9888 - val_loss: 0.1571 - val_accuracy: 0.9705
# Epoch 30/150
# 10/10 [==============================] - 1s 103ms/step - loss: 0.0475 - accuracy: 0.9864 - val_loss: 0.1405 - val_accuracy: 0.9705
# Epoch 31/150
# 10/10 [==============================] - 1s 101ms/step - loss: 0.0442 - accuracy: 0.9908 - val_loss: 0.1675 - val_accuracy: 0.9728
# Epoch 32/150
# 10/10 [==============================] - 1s 101ms/step - loss: 0.0463 - accuracy: 0.9876 - val_loss: 0.1556 - val_accuracy: 0.9705
# Epoch 33/150
# 10/10 [==============================] - 1s 123ms/step - loss: 0.0459 - accuracy: 0.9888 - val_loss: 0.1601 - val_accuracy: 0.9705
# Epoch 34/150
# 10/10 [==============================] - 1s 103ms/step - loss: 0.0408 - accuracy: 0.9892 - val_loss: 0.1830 - val_accuracy: 0.9683
# Epoch 35/150
# 10/10 [==============================] - 1s 104ms/step - loss: 0.0405 - accuracy: 0.9888 - val_loss: 0.1508 - val_accuracy: 0.9728
# Epoch 36/150
# 10/10 [==============================] - 1s 107ms/step - loss: 0.0388 - accuracy: 0.9924 - val_loss: 0.1498 - val_accuracy: 0.9751
# Epoch 37/150
# 10/10 [==============================] - 1s 107ms/step - loss: 0.0375 - accuracy: 0.9904 - val_loss: 0.1553 - val_accuracy: 0.9728
# Epoch 38/150
# 10/10 [==============================] - 1s 122ms/step - loss: 0.0440 - accuracy: 0.9864 - val_loss: 0.1920 - val_accuracy: 0.9660
# Epoch 39/150
# 10/10 [==============================] - 1s 100ms/step - loss: 0.0417 - accuracy: 0.9900 - val_loss: 0.2074 - val_accuracy: 0.9592
# Epoch 40/150
# 10/10 [==============================] - 1s 106ms/step - loss: 0.0436 - accuracy: 0.9880 - val_loss: 0.1902 - val_accuracy: 0.9660
# Epoch 41/150
# 10/10 [==============================] - 1s 102ms/step - loss: 0.0415 - accuracy: 0.9908 - val_loss: 0.1999 - val_accuracy: 0.9637
# Epoch 42/150
# 10/10 [==============================] - 1s 101ms/step - loss: 0.0321 - accuracy: 0.9924 - val_loss: 0.1777 - val_accuracy: 0.9705
# Epoch 43/150
# 10/10 [==============================] - 1s 106ms/step - loss: 0.0346 - accuracy: 0.9900 - val_loss: 0.1958 - val_accuracy: 0.9637
# Epoch 44/150
# 10/10 [==============================] - 1s 121ms/step - loss: 0.0297 - accuracy: 0.9940 - val_loss: 0.1664 - val_accuracy: 0.9773
# Epoch 45/150
# 10/10 [==============================] - 1s 101ms/step - loss: 0.0300 - accuracy: 0.9936 - val_loss: 0.1678 - val_accuracy: 0.9773
# Epoch 46/150
# 10/10 [==============================] - 1s 108ms/step - loss: 0.0248 - accuracy: 0.9944 - val_loss: 0.1909 - val_accuracy: 0.9773
# Epoch 47/150
# 10/10 [==============================] - 1s 109ms/step - loss: 0.0276 - accuracy: 0.9936 - val_loss: 0.1938 - val_accuracy: 0.9728
# Epoch 48/150
# 10/10 [==============================] - 1s 104ms/step - loss: 0.0256 - accuracy: 0.9940 - val_loss: 0.1704 - val_accuracy: 0.9751
# Epoch 49/150
# 10/10 [==============================] - 1s 104ms/step - loss: 0.0240 - accuracy: 0.9932 - val_loss: 0.1732 - val_accuracy: 0.9773
# Epoch 50/150
# 10/10 [==============================] - 1s 104ms/step - loss: 0.0253 - accuracy: 0.9956 - val_loss: 0.1950 - val_accuracy: 0.9751
# Epoch 51/150
# 10/10 [==============================] - 1s 128ms/step - loss: 0.0265 - accuracy: 0.9932 - val_loss: 0.1697 - val_accuracy: 0.9773
# Epoch 52/150
# 10/10 [==============================] - 1s 102ms/step - loss: 0.0227 - accuracy: 0.9944 - val_loss: 0.1921 - val_accuracy: 0.9773
# Epoch 53/150
# 10/10 [==============================] - 1s 100ms/step - loss: 0.0289 - accuracy: 0.9932 - val_loss: 0.1899 - val_accuracy: 0.9773
# Epoch 54/150
# 10/10 [==============================] - 1s 103ms/step - loss: 0.0303 - accuracy: 0.9908 - val_loss: 0.1954 - val_accuracy: 0.9773
# Epoch 55/150
# 10/10 [==============================] - 1s 124ms/step - loss: 0.0263 - accuracy: 0.9948 - val_loss: 0.1793 - val_accuracy: 0.9773
# Epoch 56/150
# 10/10 [==============================] - 1s 105ms/step - loss: 0.0232 - accuracy: 0.9936 - val_loss: 0.1908 - val_accuracy: 0.9773
# Epoch 57/150
# 10/10 [==============================] - 1s 104ms/step - loss: 0.0222 - accuracy: 0.9956 - val_loss: 0.1776 - val_accuracy: 0.9773
# Epoch 58/150
# 10/10 [==============================] - 1s 110ms/step - loss: 0.0235 - accuracy: 0.9948 - val_loss: 0.2093 - val_accuracy: 0.9728
# Epoch 59/150
# 10/10 [==============================] - 1s 101ms/step - loss: 0.0296 - accuracy: 0.9920 - val_loss: 0.1677 - val_accuracy: 0.9773
# Epoch 60/150
# 10/10 [==============================] - 1s 103ms/step - loss: 0.0219 - accuracy: 0.9952 - val_loss: 0.1832 - val_accuracy: 0.9773
# Epoch 61/150
# 10/10 [==============================] - 1s 121ms/step - loss: 0.0235 - accuracy: 0.9940 - val_loss: 0.1909 - val_accuracy: 0.9751
# Epoch 62/150
# 10/10 [==============================] - 1s 106ms/step - loss: 0.0214 - accuracy: 0.9944 - val_loss: 0.2057 - val_accuracy: 0.9751
# Epoch 63/150
# 10/10 [==============================] - 1s 100ms/step - loss: 0.0246 - accuracy: 0.9944 - val_loss: 0.1895 - val_accuracy: 0.9773
# Epoch 64/150
# 10/10 [==============================] - 1s 102ms/step - loss: 0.0236 - accuracy: 0.9948 - val_loss: 0.1901 - val_accuracy: 0.9773
# Epoch 65/150
# 10/10 [==============================] - 1s 100ms/step - loss: 0.0211 - accuracy: 0.9944 - val_loss: 0.1870 - val_accuracy: 0.9796
# Epoch 66/150
# 10/10 [==============================] - 1s 102ms/step - loss: 0.0195 - accuracy: 0.9960 - val_loss: 0.2113 - val_accuracy: 0.9773
# Epoch 67/150
# 10/10 [==============================] - 1s 104ms/step - loss: 0.0206 - accuracy: 0.9952 - val_loss: 0.1972 - val_accuracy: 0.9728
# Epoch 68/150
# 10/10 [==============================] - 1s 103ms/step - loss: 0.0187 - accuracy: 0.9960 - val_loss: 0.2141 - val_accuracy: 0.9751
# Epoch 69/150
# 10/10 [==============================] - 1s 104ms/step - loss: 0.0203 - accuracy: 0.9960 - val_loss: 0.1979 - val_accuracy: 0.9751
# Epoch 70/150
# 10/10 [==============================] - 1s 122ms/step - loss: 0.0201 - accuracy: 0.9948 - val_loss: 0.2303 - val_accuracy: 0.9728
# Epoch 71/150
# 10/10 [==============================] - 1s 101ms/step - loss: 0.0205 - accuracy: 0.9944 - val_loss: 0.2164 - val_accuracy: 0.9751
# Epoch 72/150
# 10/10 [==============================] - 1s 103ms/step - loss: 0.0199 - accuracy: 0.9948 - val_loss: 0.2558 - val_accuracy: 0.9637
# Epoch 73/150
# 10/10 [==============================] - 1s 105ms/step - loss: 0.0256 - accuracy: 0.9932 - val_loss: 0.2272 - val_accuracy: 0.9660
# Epoch 74/150
# 10/10 [==============================] - 1s 105ms/step - loss: 0.0261 - accuracy: 0.9944 - val_loss: 0.2037 - val_accuracy: 0.9683
# Epoch 75/150
# 10/10 [==============================] - 1s 102ms/step - loss: 0.0275 - accuracy: 0.9904 - val_loss: 0.1988 - val_accuracy: 0.9660
# Epoch 76/150
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0232 - accuracy: 0.9936 - val_loss: 0.1874 - val_accuracy: 0.9773
# Epoch 77/150
# 10/10 [==============================] - 1s 104ms/step - loss: 0.0249 - accuracy: 0.9936 - val_loss: 0.1670 - val_accuracy: 0.9751
# Epoch 78/150
# 10/10 [==============================] - 1s 100ms/step - loss: 0.0228 - accuracy: 0.9956 - val_loss: 0.1499 - val_accuracy: 0.9796
# Epoch 79/150
# 10/10 [==============================] - 1s 102ms/step - loss: 0.0277 - accuracy: 0.9940 - val_loss: 0.1974 - val_accuracy: 0.9751
# Epoch 80/150
# 10/10 [==============================] - 1s 103ms/step - loss: 0.0206 - accuracy: 0.9944 - val_loss: 0.1939 - val_accuracy: 0.9728
# Epoch 81/150
# 10/10 [==============================] - 1s 106ms/step - loss: 0.0231 - accuracy: 0.9940 - val_loss: 0.1809 - val_accuracy: 0.9728
# Epoch 82/150
# 10/10 [==============================] - 1s 106ms/step - loss: 0.0211 - accuracy: 0.9952 - val_loss: 0.2109 - val_accuracy: 0.9705
# Epoch 83/150
# 10/10 [==============================] - 1s 124ms/step - loss: 0.0195 - accuracy: 0.9956 - val_loss: 0.1831 - val_accuracy: 0.9773
# Epoch 84/150
# 10/10 [==============================] - 1s 100ms/step - loss: 0.0217 - accuracy: 0.9940 - val_loss: 0.1869 - val_accuracy: 0.9728
# Epoch 85/150
# 10/10 [==============================] - 1s 106ms/step - loss: 0.0208 - accuracy: 0.9944 - val_loss: 0.1877 - val_accuracy: 0.9773
# Epoch 86/150
# 10/10 [==============================] - 1s 104ms/step - loss: 0.0176 - accuracy: 0.9952 - val_loss: 0.2288 - val_accuracy: 0.9728
# Epoch 87/150
# 10/10 [==============================] - 1s 107ms/step - loss: 0.0195 - accuracy: 0.9944 - val_loss: 0.2106 - val_accuracy: 0.9728
# Epoch 88/150
# 10/10 [==============================] - 1s 105ms/step - loss: 0.0249 - accuracy: 0.9944 - val_loss: 0.1879 - val_accuracy: 0.9705
# Epoch 89/150
# 10/10 [==============================] - 1s 125ms/step - loss: 0.0249 - accuracy: 0.9932 - val_loss: 0.1489 - val_accuracy: 0.9796
# Epoch 90/150
# 10/10 [==============================] - 1s 104ms/step - loss: 0.0189 - accuracy: 0.9944 - val_loss: 0.1879 - val_accuracy: 0.9751
# Epoch 91/150
# 10/10 [==============================] - 1s 109ms/step - loss: 0.0274 - accuracy: 0.9912 - val_loss: 0.2223 - val_accuracy: 0.9683
# Epoch 92/150
# 10/10 [==============================] - 1s 102ms/step - loss: 0.0195 - accuracy: 0.9956 - val_loss: 0.2268 - val_accuracy: 0.9705
# Epoch 93/150
# 10/10 [==============================] - 1s 101ms/step - loss: 0.0234 - accuracy: 0.9948 - val_loss: 0.2042 - val_accuracy: 0.9773
# Epoch 94/150
# 10/10 [==============================] - 1s 103ms/step - loss: 0.0200 - accuracy: 0.9952 - val_loss: 0.1958 - val_accuracy: 0.9773
# Epoch 95/150
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0190 - accuracy: 0.9944 - val_loss: 0.2179 - val_accuracy: 0.9751
# Epoch 96/150
# 10/10 [==============================] - 1s 104ms/step - loss: 0.0179 - accuracy: 0.9964 - val_loss: 0.1765 - val_accuracy: 0.9773
# Epoch 97/150
# 10/10 [==============================] - 1s 105ms/step - loss: 0.0206 - accuracy: 0.9944 - val_loss: 0.2067 - val_accuracy: 0.9705
# Epoch 98/150
# 10/10 [==============================] - 1s 102ms/step - loss: 0.0179 - accuracy: 0.9960 - val_loss: 0.1864 - val_accuracy: 0.9751
# Epoch 99/150
# 10/10 [==============================] - 1s 105ms/step - loss: 0.0167 - accuracy: 0.9956 - val_loss: 0.1957 - val_accuracy: 0.9773
# Epoch 100/150
# 10/10 [==============================] - 1s 108ms/step - loss: 0.0158 - accuracy: 0.9968 - val_loss: 0.1971 - val_accuracy: 0.9773
# Epoch 101/150
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0171 - accuracy: 0.9964 - val_loss: 0.2418 - val_accuracy: 0.9705
# Epoch 102/150
# 10/10 [==============================] - 1s 106ms/step - loss: 0.0173 - accuracy: 0.9952 - val_loss: 0.1760 - val_accuracy: 0.9773
# Epoch 103/150
# 10/10 [==============================] - 1s 105ms/step - loss: 0.0155 - accuracy: 0.9964 - val_loss: 0.2337 - val_accuracy: 0.9728
# Epoch 104/150
# 10/10 [==============================] - 1s 101ms/step - loss: 0.0175 - accuracy: 0.9952 - val_loss: 0.2188 - val_accuracy: 0.9728
# Epoch 105/150
# 10/10 [==============================] - 1s 102ms/step - loss: 0.0172 - accuracy: 0.9944 - val_loss: 0.2262 - val_accuracy: 0.9728
# Epoch 106/150
# 10/10 [==============================] - 1s 104ms/step - loss: 0.0150 - accuracy: 0.9968 - val_loss: 0.2349 - val_accuracy: 0.9705
# Epoch 107/150
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0151 - accuracy: 0.9960 - val_loss: 0.2153 - val_accuracy: 0.9705
# Epoch 108/150
# 10/10 [==============================] - 1s 104ms/step - loss: 0.0164 - accuracy: 0.9960 - val_loss: 0.2112 - val_accuracy: 0.9728
# Epoch 109/150
# 10/10 [==============================] - 1s 106ms/step - loss: 0.0143 - accuracy: 0.9968 - val_loss: 0.2321 - val_accuracy: 0.9728
# Epoch 110/150
# 10/10 [==============================] - 1s 104ms/step - loss: 0.0160 - accuracy: 0.9964 - val_loss: 0.2042 - val_accuracy: 0.9728
# Epoch 111/150
# 10/10 [==============================] - 1s 104ms/step - loss: 0.0145 - accuracy: 0.9972 - val_loss: 0.2205 - val_accuracy: 0.9728
# Epoch 112/150
# 10/10 [==============================] - 1s 107ms/step - loss: 0.0146 - accuracy: 0.9960 - val_loss: 0.2274 - val_accuracy: 0.9728
# Epoch 113/150
# 10/10 [==============================] - 1s 118ms/step - loss: 0.0170 - accuracy: 0.9956 - val_loss: 0.2202 - val_accuracy: 0.9728
# Epoch 114/150
# 10/10 [==============================] - 1s 106ms/step - loss: 0.0170 - accuracy: 0.9956 - val_loss: 0.1835 - val_accuracy: 0.9728
# Epoch 115/150
# 10/10 [==============================] - 1s 106ms/step - loss: 0.0164 - accuracy: 0.9960 - val_loss: 0.2000 - val_accuracy: 0.9728
# Epoch 116/150
# 10/10 [==============================] - 1s 107ms/step - loss: 0.0152 - accuracy: 0.9972 - val_loss: 0.1858 - val_accuracy: 0.9728
# Epoch 117/150
# 10/10 [==============================] - 1s 101ms/step - loss: 0.0152 - accuracy: 0.9964 - val_loss: 0.2142 - val_accuracy: 0.9728
# Epoch 118/150
# 10/10 [==============================] - 1s 105ms/step - loss: 0.0141 - accuracy: 0.9972 - val_loss: 0.1806 - val_accuracy: 0.9751
# Epoch 119/150
# 10/10 [==============================] - 1s 122ms/step - loss: 0.0152 - accuracy: 0.9964 - val_loss: 0.1904 - val_accuracy: 0.9728
# Epoch 120/150
# 10/10 [==============================] - 1s 104ms/step - loss: 0.0139 - accuracy: 0.9964 - val_loss: 0.1838 - val_accuracy: 0.9773
# Epoch 121/150
# 10/10 [==============================] - 1s 101ms/step - loss: 0.0150 - accuracy: 0.9968 - val_loss: 0.1926 - val_accuracy: 0.9751
# Epoch 122/150
# 10/10 [==============================] - 1s 101ms/step - loss: 0.0128 - accuracy: 0.9964 - val_loss: 0.2119 - val_accuracy: 0.9728
# Epoch 123/150
# 10/10 [==============================] - 1s 101ms/step - loss: 0.0148 - accuracy: 0.9964 - val_loss: 0.1847 - val_accuracy: 0.9751
# Epoch 124/150
# 10/10 [==============================] - 1s 104ms/step - loss: 0.0168 - accuracy: 0.9956 - val_loss: 0.1990 - val_accuracy: 0.9728
# Epoch 125/150
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0150 - accuracy: 0.9964 - val_loss: 0.1759 - val_accuracy: 0.9773
# Epoch 126/150
# 10/10 [==============================] - 1s 104ms/step - loss: 0.0137 - accuracy: 0.9964 - val_loss: 0.2006 - val_accuracy: 0.9728
# Epoch 127/150
# 10/10 [==============================] - 1s 104ms/step - loss: 0.0144 - accuracy: 0.9956 - val_loss: 0.1576 - val_accuracy: 0.9796
# Epoch 128/150
# 10/10 [==============================] - 1s 103ms/step - loss: 0.0151 - accuracy: 0.9964 - val_loss: 0.3055 - val_accuracy: 0.9569
# Epoch 129/150
# 10/10 [==============================] - 1s 101ms/step - loss: 0.0222 - accuracy: 0.9940 - val_loss: 0.3943 - val_accuracy: 0.9206
# Epoch 130/150
# 10/10 [==============================] - 1s 118ms/step - loss: 0.0546 - accuracy: 0.9856 - val_loss: 0.2527 - val_accuracy: 0.9546
# Epoch 131/150
# 10/10 [==============================] - 1s 105ms/step - loss: 0.0271 - accuracy: 0.9908 - val_loss: 0.2570 - val_accuracy: 0.9501
# Epoch 132/150
# 10/10 [==============================] - 1s 103ms/step - loss: 0.0258 - accuracy: 0.9912 - val_loss: 0.2287 - val_accuracy: 0.9637
# Epoch 133/150
# 10/10 [==============================] - 1s 108ms/step - loss: 0.0235 - accuracy: 0.9936 - val_loss: 0.1350 - val_accuracy: 0.9773
# Epoch 134/150
# 10/10 [==============================] - 1s 101ms/step - loss: 0.0256 - accuracy: 0.9940 - val_loss: 0.2171 - val_accuracy: 0.9705
# Epoch 135/150
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0244 - accuracy: 0.9944 - val_loss: 0.1766 - val_accuracy: 0.9728
# Epoch 136/150
# 10/10 [==============================] - 1s 104ms/step - loss: 0.0180 - accuracy: 0.9952 - val_loss: 0.1812 - val_accuracy: 0.9728
# Epoch 137/150
# 10/10 [==============================] - 1s 102ms/step - loss: 0.0188 - accuracy: 0.9956 - val_loss: 0.2404 - val_accuracy: 0.9615
# Epoch 138/150
# 10/10 [==============================] - 1s 103ms/step - loss: 0.0237 - accuracy: 0.9940 - val_loss: 0.1662 - val_accuracy: 0.9728
# Epoch 139/150
# 10/10 [==============================] - 1s 103ms/step - loss: 0.0199 - accuracy: 0.9960 - val_loss: 0.1923 - val_accuracy: 0.9773
# Epoch 140/150
# 10/10 [==============================] - 1s 119ms/step - loss: 0.0182 - accuracy: 0.9964 - val_loss: 0.1969 - val_accuracy: 0.9773
# Epoch 141/150
# 10/10 [==============================] - 1s 103ms/step - loss: 0.0149 - accuracy: 0.9964 - val_loss: 0.2029 - val_accuracy: 0.9728
# Epoch 142/150
# 10/10 [==============================] - 1s 103ms/step - loss: 0.0163 - accuracy: 0.9968 - val_loss: 0.2081 - val_accuracy: 0.9728
# Epoch 143/150
# 10/10 [==============================] - 1s 101ms/step - loss: 0.0149 - accuracy: 0.9964 - val_loss: 0.2156 - val_accuracy: 0.9728
# Epoch 144/150
# 10/10 [==============================] - 1s 104ms/step - loss: 0.0155 - accuracy: 0.9964 - val_loss: 0.2082 - val_accuracy: 0.9751
# Epoch 145/150
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0159 - accuracy: 0.9964 - val_loss: 0.2293 - val_accuracy: 0.9728
# Epoch 146/150
# 10/10 [==============================] - 1s 107ms/step - loss: 0.0140 - accuracy: 0.9960 - val_loss: 0.2157 - val_accuracy: 0.9728
# Epoch 147/150
# 10/10 [==============================] - 1s 106ms/step - loss: 0.0140 - accuracy: 0.9972 - val_loss: 0.2365 - val_accuracy: 0.9728
# Epoch 148/150
# 10/10 [==============================] - 1s 107ms/step - loss: 0.0132 - accuracy: 0.9968 - val_loss: 0.2145 - val_accuracy: 0.9773
# Epoch 149/150
# 10/10 [==============================] - 1s 105ms/step - loss: 0.0155 - accuracy: 0.9960 - val_loss: 0.2615 - val_accuracy: 0.9683
# Epoch 150/150
# 10/10 [==============================] - 1s 129ms/step - loss: 0.0143 - accuracy: 0.9960 - val_loss: 0.1812 - val_accuracy: 0.9773

# %% [markdown]
# Рисуем график модели

# %%
utils.plot_model(model_final, show_shapes=True, show_layer_names=True, dpi=60, show_layer_activations=True, show_trainable=True)

# %%
scores = model_final.evaluate([x1_test, x2_test, x3_test],
                        y_test,
                        verbose=1
                        )
scores2 = model_final.evaluate([x1_val, x2_val, x3_val],
                        y_val,
                        verbose=1
                        )
plt.plot(history.history['accuracy'],
         label='Доля верных ответов на обучающем наборе')

# Визуализация точности на проверочной выборке
plt.plot(history.history['val_accuracy'],
         label='Доля верных ответов на проверочном наборе')

# Отрисовка подписей осей
plt.xlabel('Эпоха обучения')
plt.ylabel('Доля верных ответов')

# Отрисовка легенды
plt.legend()

# Вывод графика
plt.show()


plt.plot(history.history['loss'],
         label='Ошибка на обучающем наборе')

plt.plot(history.history['val_loss'],
         label='Ошибка на проверочном наборе')

plt.xlabel('Эпоха обучения')
plt.ylabel('Ошибка')

plt.legend()

plt.show()
# Out:
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0989 - accuracy: 0.9725
# 11/11 [==============================] - 0s 14ms/step - loss: 0.1381 - accuracy: 0.9786

# %%
y_pred = model_final.predict([x1_test, x2_test, x3_test])

y_pred2=np.argmax(y_pred, axis=1)
y_test2=np.argmax(y_test, axis=1)
cm_data = confusion_matrix(y_test2, y_pred2)


sns.heatmap(cm_data,
            annot=True,
            fmt='g',
            xticklabels=['Годен', 'Ограниченно годен', 'Не годен'],
            yticklabels=['Годен', 'Ограниченно годен', 'Не годен'])

cm_data
# Out:
# 12/12 [==============================] - 0s 11ms/step
# array([[138,  10,   0],
#        [  0, 198,   0],
#        [  0,   0,  17]], dtype=int64)
