# %% [markdown]
# <a href="https://colab.research.google.com/github/Untick/InspectrumClinic_RS_gr2/blob/main/Fedoseev%20Sergey/%D0%A1%D1%82%D0%B0%D0%B6%D0%B8%D1%80%D0%BE%D0%B2%D0%BA%D0%B0_%D0%9F%D1%80%D0%BE%D1%84%D0%BF%D0%B0%D1%82%D0%BE%D0%BB%D0%BE%D0%B3_21_06_28_06_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Исследование датасета

# %%
# Импорт библиотеки для работы с массивами данных
import numpy as np

# Импорт библиотеки для работы с таблицами
import pandas as pd

# Загрузка файла из облака в colab https://drive.google.com/file/d/1NfvE3AheuFFLLRAKzpKl2I6TYVs5MQSB/view?usp=sharing
import gdown
#gdown.download('https://storage.yandexcloud.net/terratraineeship/23_InspectrumClinic_RS/datasets/26.06%20new%20dataset.zip', None, quiet=True)
gdown.download('https://drive.google.com/file/d/1NfvE3AheuFFLLRAKzpKl2I6TYVs5MQSB/view?usp=sharing', None, quiet=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/parse_url.py:35: UserWarning: You specified a Google Drive link that is not the correct link to download a file. You might want to try `--fuzzy` option or the following url: https://drive.google.com/uc?id=1NfvE3AheuFFLLRAKzpKl2I6TYVs5MQSB
#   warnings.warn(
# 'view?usp=sharing'

# %%
# Создадаем переменную data, в которую с помощью функции pd.read_csv() загружаем данные из файла
data = pd.read_csv('view?usp=sharing')
# Вывод датасета на экран
data
# Out:
#     <!DOCTYPE html><html><head><meta name="google" content="notranslate"><meta http-equiv="X-UA-Compatible" content="IE=edge;"><style nonce="XkTqIA6cjOZlg49SH1DtUQ">@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmSU5fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:700;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmWUlfBBc9.ttf)format('truetype');}</style><meta name="referrer" content="origin"><title>neiro_06-23.csv - Google Drive</title><meta property="og:title" content="neiro_06-23.csv"><meta property="og:type" content="article"><meta property="og:site_name" content="Google Docs"><meta property="og:url" content="https://drive.google.com/file/d/1NfvE3AheuFFLLRAKzpKl2I6TYVs5MQSB/view?usp=sharing&amp;usp=embed_facebook"><link rel="shortcut icon" href="https://ssl.gstatic.com/images/branding/product/1x/drive_2020q4_32dp.png"><link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Google+Sans_old:300  \
# 0                                                 try{
# 1                                                   /*
# 2               Copyright The Closure Library Authors.
# 3                  SPDX-License-Identifier: Apache-2.0
# 4                                                   */
# ..                                                 ...
# 119                                  var Xj=function(a
# 120                     }catch(e){_._DumpException(e)}
# 121                                    })(this.gbar_);
# 122                                     // Google Inc.
# 123  </script><script id="base-js" async type="text...
#
#                                                    400             500  \
# 0                                                  NaN             NaN
# 1                                                  NaN             NaN
# 2                                                  NaN             NaN
# 3                                                  NaN             NaN
# 4                                                  NaN             NaN
# ..                                                 ...             ...
# 119                                                  b  c){_.te.log(46
# 120                                                NaN             NaN
# 121                                                NaN             NaN
# 122                                                NaN             NaN
# 123  wb" nonce="-o_XDzxvZeNN7j4iZH1T0A"></script></...             NaN
#
#     700" nonce="XkTqIA6cjOZlg49SH1DtUQ"><link rel="stylesheet" href="https://www.gstatic.com/_/apps-fileview/_/ss/k=apps-fileview.v.DriA_IFvW2k.L.X.O/am=AAAE/d=0/rs=AO0039t5O-8MFsEJHYkgP4E91wxVAJ-fhg" nonce="XkTqIA6cjOZlg49SH1DtUQ"><script nonce="-o_XDzxvZeNN7j4iZH1T0A">_docs_flag_initialData={"docs-ails":"docs_cold"  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 119                                             {att:a
# 120                                                NaN
# 121                                                NaN
# 122                                                NaN
# 123                                                NaN
#
#     docs-fwds:"docs_sdf" docs-crs:"docs_crs_nl"   docs-fe-re:2 docs-fl:1  \
# 0                    NaN                    NaN            NaN       NaN
# 1                    NaN                    NaN            NaN       NaN
# 2                    NaN                    NaN            NaN       NaN
# 3                    NaN                    NaN            NaN       NaN
# 4                    NaN                    NaN            NaN       NaN
# ..                   ...                    ...            ...       ...
# 119                max:b               url:c})}  Zj=function(a         b
# 120                  NaN                    NaN            NaN       NaN
# 121                  NaN                    NaN            NaN       NaN
# 122                  NaN                    NaN            NaN       NaN
# 123                  NaN                    NaN            NaN       NaN
#
#         docs-l1lc:2 docs-l1lm:"IAD"  ... 0.84 0.85 0.86 0.87 1].11 [[null.2  \
# 0               NaN             NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 1               NaN             NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 2               NaN             NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 3               NaN             NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 4               NaN             NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
# ..              ...             ...  ...  ...  ...  ...  ...   ...      ...
# 119  c){_.te.log(47          {att:a  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 120             NaN             NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 121             NaN             NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 122             NaN             NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 123             NaN             NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
#
#     null.209 null.210  \
# 0        NaN      NaN
# 1        NaN      NaN
# 2        NaN      NaN
# 3        NaN      NaN
# 4        NaN      NaN
# ..       ...      ...
# 119      NaN      NaN
# 120      NaN      NaN
# 121      NaN      NaN
# 122      NaN      NaN
# 123      NaN      NaN
#
#     https://www.gstatic.com/og/_/js/k=og.qtm.en_US.KlEpQsPRe98.es5.O/rt=j/m=qabr,q_dnp,qapid/exm=qaaw,qadd,qaid,qein,qhaw,qhba,qhbr,qhch,qhga,qhid,qhin/d=1/ed=1/rs=AA2YrTvurMKAfdIDPl9rhLbHMQMOBwKSuQ]]]]  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 119                                                NaN
# 120                                                NaN
# 121                                                NaN
# 122                                                NaN
# 123                                                NaN
#
#     };this.gbar_=this.gbar_||{};(function(_){var window=this;
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 119                                                NaN
# 120                                                NaN
# 121                                                NaN
# 122                                                NaN
# 123                                                NaN
#
# [124 rows x 840 columns]

# %%
# Создание копии датасета
data_backup = data.copy()
# Вывод на экран первых и последних пяти строк
data.head()
# Out:
#   <!DOCTYPE html><html><head><meta name="google" content="notranslate"><meta http-equiv="X-UA-Compatible" content="IE=edge;"><style nonce="XkTqIA6cjOZlg49SH1DtUQ">@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmSU5fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:700;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmWUlfBBc9.ttf)format('truetype');}</style><meta name="referrer" content="origin"><title>neiro_06-23.csv - Google Drive</title><meta property="og:title" content="neiro_06-23.csv"><meta property="og:type" content="article"><meta property="og:site_name" content="Google Docs"><meta property="og:url" content="https://drive.google.com/file/d/1NfvE3AheuFFLLRAKzpKl2I6TYVs5MQSB/view?usp=sharing&amp;usp=embed_facebook"><link rel="shortcut icon" href="https://ssl.gstatic.com/images/branding/product/1x/drive_2020q4_32dp.png"><link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Google+Sans_old:300  \
# 0                                               try{
# 1                                                 /*
# 2             Copyright The Closure Library Authors.
# 3                SPDX-License-Identifier: Apache-2.0
# 4                                                 */
#
#    400  500  \
# 0  NaN  NaN
# 1  NaN  NaN
# 2  NaN  NaN
# 3  NaN  NaN
# 4  NaN  NaN
#
#   700" nonce="XkTqIA6cjOZlg49SH1DtUQ"><link rel="stylesheet" href="https://www.gstatic.com/_/apps-fileview/_/ss/k=apps-fileview.v.DriA_IFvW2k.L.X.O/am=AAAE/d=0/rs=AO0039t5O-8MFsEJHYkgP4E91wxVAJ-fhg" nonce="XkTqIA6cjOZlg49SH1DtUQ"><script nonce="-o_XDzxvZeNN7j4iZH1T0A">_docs_flag_initialData={"docs-ails":"docs_cold"  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   docs-fwds:"docs_sdf" docs-crs:"docs_crs_nl" docs-fe-re:2 docs-fl:1  \
# 0                  NaN                    NaN          NaN       NaN
# 1                  NaN                    NaN          NaN       NaN
# 2                  NaN                    NaN          NaN       NaN
# 3                  NaN                    NaN          NaN       NaN
# 4                  NaN                    NaN          NaN       NaN
#
#   docs-l1lc:2 docs-l1lm:"IAD"  ... 0.84 0.85 0.86 0.87 1].11 [[null.2  \
# 0         NaN             NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 1         NaN             NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 2         NaN             NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 3         NaN             NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 4         NaN             NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
#
#   null.209 null.210  \
# 0      NaN      NaN
# 1      NaN      NaN
# 2      NaN      NaN
# 3      NaN      NaN
# 4      NaN      NaN
#
#   https://www.gstatic.com/og/_/js/k=og.qtm.en_US.KlEpQsPRe98.es5.O/rt=j/m=qabr,q_dnp,qapid/exm=qaaw,qadd,qaid,qein,qhaw,qhba,qhbr,qhch,qhga,qhid,qhin/d=1/ed=1/rs=AA2YrTvurMKAfdIDPl9rhLbHMQMOBwKSuQ]]]]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   };this.gbar_=this.gbar_||{};(function(_){var window=this;
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 840 columns]

# %%
data.tail()
# Out:
#     <!DOCTYPE html><html><head><meta name="google" content="notranslate"><meta http-equiv="X-UA-Compatible" content="IE=edge;"><style nonce="XkTqIA6cjOZlg49SH1DtUQ">@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmSU5fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:700;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmWUlfBBc9.ttf)format('truetype');}</style><meta name="referrer" content="origin"><title>neiro_06-23.csv - Google Drive</title><meta property="og:title" content="neiro_06-23.csv"><meta property="og:type" content="article"><meta property="og:site_name" content="Google Docs"><meta property="og:url" content="https://drive.google.com/file/d/1NfvE3AheuFFLLRAKzpKl2I6TYVs5MQSB/view?usp=sharing&amp;usp=embed_facebook"><link rel="shortcut icon" href="https://ssl.gstatic.com/images/branding/product/1x/drive_2020q4_32dp.png"><link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Google+Sans_old:300  \
# 119                                  var Xj=function(a
# 120                     }catch(e){_._DumpException(e)}
# 121                                    })(this.gbar_);
# 122                                     // Google Inc.
# 123  </script><script id="base-js" async type="text...
#
#                                                    400             500  \
# 119                                                  b  c){_.te.log(46
# 120                                                NaN             NaN
# 121                                                NaN             NaN
# 122                                                NaN             NaN
# 123  wb" nonce="-o_XDzxvZeNN7j4iZH1T0A"></script></...             NaN
#
#     700" nonce="XkTqIA6cjOZlg49SH1DtUQ"><link rel="stylesheet" href="https://www.gstatic.com/_/apps-fileview/_/ss/k=apps-fileview.v.DriA_IFvW2k.L.X.O/am=AAAE/d=0/rs=AO0039t5O-8MFsEJHYkgP4E91wxVAJ-fhg" nonce="XkTqIA6cjOZlg49SH1DtUQ"><script nonce="-o_XDzxvZeNN7j4iZH1T0A">_docs_flag_initialData={"docs-ails":"docs_cold"  \
# 119                                             {att:a
# 120                                                NaN
# 121                                                NaN
# 122                                                NaN
# 123                                                NaN
#
#     docs-fwds:"docs_sdf" docs-crs:"docs_crs_nl"   docs-fe-re:2 docs-fl:1  \
# 119                max:b               url:c})}  Zj=function(a         b
# 120                  NaN                    NaN            NaN       NaN
# 121                  NaN                    NaN            NaN       NaN
# 122                  NaN                    NaN            NaN       NaN
# 123                  NaN                    NaN            NaN       NaN
#
#         docs-l1lc:2 docs-l1lm:"IAD"  ... 0.84 0.85 0.86 0.87 1].11 [[null.2  \
# 119  c){_.te.log(47          {att:a  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 120             NaN             NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 121             NaN             NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 122             NaN             NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 123             NaN             NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
#
#     null.209 null.210  \
# 119      NaN      NaN
# 120      NaN      NaN
# 121      NaN      NaN
# 122      NaN      NaN
# 123      NaN      NaN
#
#     https://www.gstatic.com/og/_/js/k=og.qtm.en_US.KlEpQsPRe98.es5.O/rt=j/m=qabr,q_dnp,qapid/exm=qaaw,qadd,qaid,qein,qhaw,qhba,qhbr,qhch,qhga,qhid,qhin/d=1/ed=1/rs=AA2YrTvurMKAfdIDPl9rhLbHMQMOBwKSuQ]]]]  \
# 119                                                NaN
# 120                                                NaN
# 121                                                NaN
# 122                                                NaN
# 123                                                NaN
#
#     };this.gbar_=this.gbar_||{};(function(_){var window=this;
# 119                                                NaN
# 120                                                NaN
# 121                                                NaN
# 122                                                NaN
# 123                                                NaN
#
# [5 rows x 840 columns]

# %%
# Анализ датасета
data.shape
# Out:
# (124, 840)

# %%
data.size
# Out:
# 104160

# %%
data.count
# Out:
# <bound method DataFrame.count of     <!DOCTYPE html><html><head><meta name="google" content="notranslate"><meta http-equiv="X-UA-Compatible" content="IE=edge;"><style nonce="XkTqIA6cjOZlg49SH1DtUQ">@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmSU5fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:700;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmWUlfBBc9.ttf)format('truetype');}</style><meta name="referrer" content="origin"><title>neiro_06-23.csv - Google Drive</title><meta property="og:title" content="neiro_06-23.csv"><meta property="og:type" content="article"><meta property="og:site_name" content="Google Docs"><meta property="og:url" content="https://drive.google.com/file/d/1NfvE3AheuFFLLRAKzpKl2I6TYVs5MQSB/view?usp=sharing&amp;usp=embed_facebook"><link rel="shortcut icon" href="https://ssl.gstatic.com/images/branding/product/1x/drive_2020q4_32dp.png"><link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Google+Sans_old:300  \
# 0                                                 try{
# 1                                                   /*
# 2               Copyright The Closure Library Authors.
# 3                  SPDX-License-Identifier: Apache-2.0
# 4                                                   */
# ..                                                 ...
# 119                                  var Xj=function(a
# 120                     }catch(e){_._DumpException(e)}
# 121                                    })(this.gbar_);
# 122                                     // Google Inc.
# 123  </script><script id="base-js" async type="text...
#
#                                                    400             500  \
# 0                                                  NaN             NaN
# 1                                                  NaN             NaN
# 2                                                  NaN             NaN
# 3                                                  NaN             NaN
# 4                                                  NaN             NaN
# ..                                                 ...             ...
# 119                                                  b  c){_.te.log(46
# 120                                                NaN             NaN
# 121                                                NaN             NaN
# 122                                                NaN             NaN
# 123  wb" nonce="-o_XDzxvZeNN7j4iZH1T0A"></script></...             NaN
#
#     700" nonce="XkTqIA6cjOZlg49SH1DtUQ"><link rel="stylesheet" href="https://www.gstatic.com/_/apps-fileview/_/ss/k=apps-fileview.v.DriA_IFvW2k.L.X.O/am=AAAE/d=0/rs=AO0039t5O-8MFsEJHYkgP4E91wxVAJ-fhg" nonce="XkTqIA6cjOZlg49SH1DtUQ"><script nonce="-o_XDzxvZeNN7j4iZH1T0A">_docs_flag_initialData={"docs-ails":"docs_cold"  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 119                                             {att:a
# 120                                                NaN
# 121                                                NaN
# 122                                                NaN
# 123                                                NaN
#
#     docs-fwds:"docs_sdf" docs-crs:"docs_crs_nl"   docs-fe-re:2 docs-fl:1  \
# 0                    NaN                    NaN            NaN       NaN
# 1                    NaN                    NaN            NaN       NaN
# 2                    NaN                    NaN            NaN       NaN
# 3                    NaN                    NaN            NaN       NaN
# 4                    NaN                    NaN            NaN       NaN
# ..                   ...                    ...            ...       ...
# 119                max:b               url:c})}  Zj=function(a         b
# 120                  NaN                    NaN            NaN       NaN
# 121                  NaN                    NaN            NaN       NaN
# 122                  NaN                    NaN            NaN       NaN
# 123                  NaN                    NaN            NaN       NaN
#
#         docs-l1lc:2 docs-l1lm:"IAD"  ... 0.84 0.85 0.86 0.87 1].11 [[null.2  \
# 0               NaN             NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 1               NaN             NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 2               NaN             NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 3               NaN             NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 4               NaN             NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
# ..              ...             ...  ...  ...  ...  ...  ...   ...      ...
# 119  c){_.te.log(47          {att:a  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 120             NaN             NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 121             NaN             NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 122             NaN             NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 123             NaN             NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
#
#     null.209 null.210  \
# 0        NaN      NaN
# 1        NaN      NaN
# 2        NaN      NaN
# 3        NaN      NaN
# 4        NaN      NaN
# ..       ...      ...
# 119      NaN      NaN
# 120      NaN      NaN
# 121      NaN      NaN
# 122      NaN      NaN
# 123      NaN      NaN
#
#     https://www.gstatic.com/og/_/js/k=og.qtm.en_US.KlEpQsPRe98.es5.O/rt=j/m=qabr,q_dnp,qapid/exm=qaaw,qadd,qaid,qein,qhaw,qhba,qhbr,qhch,qhga,qhid,qhin/d=1/ed=1/rs=AA2YrTvurMKAfdIDPl9rhLbHMQMOBwKSuQ]]]]  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 119                                                NaN
# 120                                                NaN
# 121                                                NaN
# 122                                                NaN
# 123                                                NaN
#
#     };this.gbar_=this.gbar_||{};(function(_){var window=this;
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 119                                                NaN
# 120                                                NaN
# 121                                                NaN
# 122                                                NaN
# 123                                                NaN
#
# [124 rows x 840 columns]>

# %%
data.info
# Out:
# <bound method DataFrame.info of     <!DOCTYPE html><html><head><meta name="google" content="notranslate"><meta http-equiv="X-UA-Compatible" content="IE=edge;"><style nonce="XkTqIA6cjOZlg49SH1DtUQ">@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmSU5fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:700;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmWUlfBBc9.ttf)format('truetype');}</style><meta name="referrer" content="origin"><title>neiro_06-23.csv - Google Drive</title><meta property="og:title" content="neiro_06-23.csv"><meta property="og:type" content="article"><meta property="og:site_name" content="Google Docs"><meta property="og:url" content="https://drive.google.com/file/d/1NfvE3AheuFFLLRAKzpKl2I6TYVs5MQSB/view?usp=sharing&amp;usp=embed_facebook"><link rel="shortcut icon" href="https://ssl.gstatic.com/images/branding/product/1x/drive_2020q4_32dp.png"><link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Google+Sans_old:300  \
# 0                                                 try{
# 1                                                   /*
# 2               Copyright The Closure Library Authors.
# 3                  SPDX-License-Identifier: Apache-2.0
# 4                                                   */
# ..                                                 ...
# 119                                  var Xj=function(a
# 120                     }catch(e){_._DumpException(e)}
# 121                                    })(this.gbar_);
# 122                                     // Google Inc.
# 123  </script><script id="base-js" async type="text...
#
#                                                    400             500  \
# 0                                                  NaN             NaN
# 1                                                  NaN             NaN
# 2                                                  NaN             NaN
# 3                                                  NaN             NaN
# 4                                                  NaN             NaN
# ..                                                 ...             ...
# 119                                                  b  c){_.te.log(46
# 120                                                NaN             NaN
# 121                                                NaN             NaN
# 122                                                NaN             NaN
# 123  wb" nonce="-o_XDzxvZeNN7j4iZH1T0A"></script></...             NaN
#
#     700" nonce="XkTqIA6cjOZlg49SH1DtUQ"><link rel="stylesheet" href="https://www.gstatic.com/_/apps-fileview/_/ss/k=apps-fileview.v.DriA_IFvW2k.L.X.O/am=AAAE/d=0/rs=AO0039t5O-8MFsEJHYkgP4E91wxVAJ-fhg" nonce="XkTqIA6cjOZlg49SH1DtUQ"><script nonce="-o_XDzxvZeNN7j4iZH1T0A">_docs_flag_initialData={"docs-ails":"docs_cold"  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 119                                             {att:a
# 120                                                NaN
# 121                                                NaN
# 122                                                NaN
# 123                                                NaN
#
#     docs-fwds:"docs_sdf" docs-crs:"docs_crs_nl"   docs-fe-re:2 docs-fl:1  \
# 0                    NaN                    NaN            NaN       NaN
# 1                    NaN                    NaN            NaN       NaN
# 2                    NaN                    NaN            NaN       NaN
# 3                    NaN                    NaN            NaN       NaN
# 4                    NaN                    NaN            NaN       NaN
# ..                   ...                    ...            ...       ...
# 119                max:b               url:c})}  Zj=function(a         b
# 120                  NaN                    NaN            NaN       NaN
# 121                  NaN                    NaN            NaN       NaN
# 122                  NaN                    NaN            NaN       NaN
# 123                  NaN                    NaN            NaN       NaN
#
#         docs-l1lc:2 docs-l1lm:"IAD"  ... 0.84 0.85 0.86 0.87 1].11 [[null.2  \
# 0               NaN             NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 1               NaN             NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 2               NaN             NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 3               NaN             NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 4               NaN             NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
# ..              ...             ...  ...  ...  ...  ...  ...   ...      ...
# 119  c){_.te.log(47          {att:a  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 120             NaN             NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 121             NaN             NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 122             NaN             NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 123             NaN             NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
#
#     null.209 null.210  \
# 0        NaN      NaN
# 1        NaN      NaN
# 2        NaN      NaN
# 3        NaN      NaN
# 4        NaN      NaN
# ..       ...      ...
# 119      NaN      NaN
# 120      NaN      NaN
# 121      NaN      NaN
# 122      NaN      NaN
# 123      NaN      NaN
#
#     https://www.gstatic.com/og/_/js/k=og.qtm.en_US.KlEpQsPRe98.es5.O/rt=j/m=qabr,q_dnp,qapid/exm=qaaw,qadd,qaid,qein,qhaw,qhba,qhbr,qhch,qhga,qhid,qhin/d=1/ed=1/rs=AA2YrTvurMKAfdIDPl9rhLbHMQMOBwKSuQ]]]]  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 119                                                NaN
# 120                                                NaN
# 121                                                NaN
# 122                                                NaN
# 123                                                NaN
#
#     };this.gbar_=this.gbar_||{};(function(_){var window=this;
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 119                                                NaN
# 120                                                NaN
# 121                                                NaN
# 122                                                NaN
# 123                                                NaN
#
# [124 rows x 840 columns]>

# %%
# Количетво пустых ячеек?
data.isna().sum()
# Out:
# <!DOCTYPE html><html><head><meta name="google" content="notranslate"><meta http-equiv="X-UA-Compatible" content="IE=edge;"><style nonce="XkTqIA6cjOZlg49SH1DtUQ">@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmSU5fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:700;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmWUlfBBc9.ttf)format('truetype');}</style><meta name="referrer" content="origin"><title>neiro_06-23.csv - Google Drive</title><meta property="og:title" content="neiro_06-23.csv"><meta property="og:type" content="article"><meta property="og:site_name" content="Google Docs"><meta property="og:url" content="https://drive.google.com/file/d/1NfvE3AheuFFLLRAKzpKl2I6TYVs5MQSB/view?usp=sharing&amp;usp=embed_facebook"><link rel="shortcut icon" href="https://ssl.gstatic.com/images/branding/product/1x/drive_2020q4_32dp.png"><link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Google+Sans_old:300      0
# 400                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       48
# 500                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       54
# 700" nonce="XkTqIA6cjOZlg49SH1DtUQ"><link rel="stylesheet" href="https://www.gstatic.com/_/apps-fileview/_/ss/k=apps-fileview.v.DriA_IFvW2k.L.X.O/am=AAAE/d=0/rs=AO0039t5O-8MFsEJHYkgP4E91wxVAJ-fhg" nonce="XkTqIA6cjOZlg49SH1DtUQ"><script nonce="-o_XDzxvZeNN7j4iZH1T0A">_docs_flag_initialData={"docs-ails":"docs_cold"                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                58
# docs-fwds:"docs_sdf"                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      61
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...
# [[null.2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 124
# null.209                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 124
# null.210                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 124
# https://www.gstatic.com/og/_/js/k=og.qtm.en_US.KlEpQsPRe98.es5.O/rt=j/m=qabr,q_dnp,qapid/exm=qaaw,qadd,qaid,qein,qhaw,qhba,qhbr,qhch,qhga,qhid,qhin/d=1/ed=1/rs=AA2YrTvurMKAfdIDPl9rhLbHMQMOBwKSuQ]]]]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   124
# };this.gbar_=this.gbar_||{};(function(_){var window=this;                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                124
# Length: 840, dtype: int64

# %%
# Доля пропусков от общего количества элементов
data.isna().sum() / data.shape[0]
# Out:
# <!DOCTYPE html><html><head><meta name="google" content="notranslate"><meta http-equiv="X-UA-Compatible" content="IE=edge;"><style nonce="XkTqIA6cjOZlg49SH1DtUQ">@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmSU5fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:700;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmWUlfBBc9.ttf)format('truetype');}</style><meta name="referrer" content="origin"><title>neiro_06-23.csv - Google Drive</title><meta property="og:title" content="neiro_06-23.csv"><meta property="og:type" content="article"><meta property="og:site_name" content="Google Docs"><meta property="og:url" content="https://drive.google.com/file/d/1NfvE3AheuFFLLRAKzpKl2I6TYVs5MQSB/view?usp=sharing&amp;usp=embed_facebook"><link rel="shortcut icon" href="https://ssl.gstatic.com/images/branding/product/1x/drive_2020q4_32dp.png"><link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Google+Sans_old:300    0.000000
# 400                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      0.387097
# 500                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      0.435484
# 700" nonce="XkTqIA6cjOZlg49SH1DtUQ"><link rel="stylesheet" href="https://www.gstatic.com/_/apps-fileview/_/ss/k=apps-fileview.v.DriA_IFvW2k.L.X.O/am=AAAE/d=0/rs=AO0039t5O-8MFsEJHYkgP4E91wxVAJ-fhg" nonce="XkTqIA6cjOZlg49SH1DtUQ"><script nonce="-o_XDzxvZeNN7j4iZH1T0A">_docs_flag_initialData={"docs-ails":"docs_cold"                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               0.467742
# docs-fwds:"docs_sdf"                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     0.491935
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
# [[null.2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 1.000000
# null.209                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 1.000000
# null.210                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 1.000000
# https://www.gstatic.com/og/_/js/k=og.qtm.en_US.KlEpQsPRe98.es5.O/rt=j/m=qabr,q_dnp,qapid/exm=qaaw,qadd,qaid,qein,qhaw,qhba,qhbr,qhch,qhga,qhid,qhin/d=1/ed=1/rs=AA2YrTvurMKAfdIDPl9rhLbHMQMOBwKSuQ]]]]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   1.000000
# };this.gbar_=this.gbar_||{};(function(_){var window=this;                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                1.000000
# Length: 840, dtype: float64

# %%
# Общее количество пропусков
data.isna().sum().sum()
# Out:
# 102517

# %%
# Процент пропусков в ячейках (данное действие не очень информативно, больше для сведений)
proc = data.isna().sum().sum() / data.size
print('{:.1%}'.format(proc))
# Out:
# 98.4%

# %%
# Параметр include=['O'] метода .describe() выведет статистику для строковых данных:

# count - количество заполненных элементов
# unique - количество уникальных элементов
# top - самый распространенный элемент
# freq - сколько раз встречается самый распространенный элемент

# Вывод статистики для строковых данных.
data.describe(include=['O'])
# Out:
#        <!DOCTYPE html><html><head><meta name="google" content="notranslate"><meta http-equiv="X-UA-Compatible" content="IE=edge;"><style nonce="XkTqIA6cjOZlg49SH1DtUQ">@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmSU5fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:700;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmWUlfBBc9.ttf)format('truetype');}</style><meta name="referrer" content="origin"><title>neiro_06-23.csv - Google Drive</title><meta property="og:title" content="neiro_06-23.csv"><meta property="og:type" content="article"><meta property="og:site_name" content="Google Docs"><meta property="og:url" content="https://drive.google.com/file/d/1NfvE3AheuFFLLRAKzpKl2I6TYVs5MQSB/view?usp=sharing&amp;usp=embed_facebook"><link rel="shortcut icon" href="https://ssl.gstatic.com/images/branding/product/1x/drive_2020q4_32dp.png"><link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Google+Sans_old:300  \
# count                                                 124
# unique                                                 88
# top                                                  try{
# freq                                                   16
#
#        400 500  \
# count   76  70
# unique  55  65
# top      b   c
# freq    17   6
#
#        700" nonce="XkTqIA6cjOZlg49SH1DtUQ"><link rel="stylesheet" href="https://www.gstatic.com/_/apps-fileview/_/ss/k=apps-fileview.v.DriA_IFvW2k.L.X.O/am=AAAE/d=0/rs=AO0039t5O-8MFsEJHYkgP4E91wxVAJ-fhg" nonce="XkTqIA6cjOZlg49SH1DtUQ"><script nonce="-o_XDzxvZeNN7j4iZH1T0A">_docs_flag_initialData={"docs-ails":"docs_cold"  \
# count                                                  66
# unique                                                 59
# top                                                     b
# freq                                                    5
#
#        docs-fwds:"docs_sdf" docs-crs:"docs_crs_nl" docs-fe-re:2 docs-fl:1  \
# count                    63                     60           54        48
# unique                   59                     53           52        44
# top                       c                      b            c         b
# freq                      2                      6            2         5
#
#        docs-l1lc:2 docs-l1lm:"IAD"  ... Unnamed: 518      Unnamed: 519  \
# count           46              43  ...            1                 1
# unique          46              42  ...            1                 1
# top             ab               b  ...         .15)  0 1px 2px rgba(0
# freq             1               2  ...            1                 1
#
#                                  1.40  0.26              0.27  \
# count                               1     1                 1
# unique                              1     1                 1
# top     .2);box-shadow:0 1px 0 rgba(0  .15)  0 1px 2px rgba(0
# freq                                1     1                 1
#
#                     1].7                                           null.101  \
# count                  1                                                  1
# unique                 1                                                  1
# top     .2)}.gb_bb .gb_b  .gb_cb .gb_b{position:absolute;right:1px}.gb_b...
# freq                   1                                                  1
#
#                1.41                                           [[null.1  \
# count             1                                                  1
# unique            1                                                  1
# top     .gb_db.gb_x  .gb_Fa.gb_x{-webkit-flex:0 1 auto;-webkit-box-...
# freq              1                                                  1
#
#                                                  null.102
# count                                                   1
# unique                                                  1
# top     .gb_hb .gb_j{right:0;top:0}.gb_b .gb_d{padding...
# freq                                                    1
#
# [4 rows x 336 columns]
