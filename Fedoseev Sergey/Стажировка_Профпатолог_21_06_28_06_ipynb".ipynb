# %% [markdown]
# <a href="https://colab.research.google.com/github/Untick/InspectrumClinic_RS_gr2/blob/main/Fedoseev%20Sergey/%D0%A1%D1%82%D0%B0%D0%B6%D0%B8%D1%80%D0%BE%D0%B2%D0%BA%D0%B0_%D0%9F%D1%80%D0%BE%D1%84%D0%BF%D0%B0%D1%82%D0%BE%D0%BB%D0%BE%D0%B3_21_06_28_06_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Исследование датасета

# %%
# Импорт библиотеки для работы с массивами данных
import numpy as np

# Импорт библиотеки для работы с таблицами
import pandas as pd

# Загрузка файла из облака в colab https://drive.google.com/file/d/1NfvE3AheuFFLLRAKzpKl2I6TYVs5MQSB/view?usp=sharing
import gdown
gdown.download('https://drive.google.com/uc?id=1NfvE3AheuFFLLRAKzpKl2I6TYVs5MQSB', None, quiet=True)
# gdown.download('https://drive.google.com/file/d/1NfvE3AheuFFLLRAKzpKl2I6TYVs5MQSB/view?usp=sharing', None, quiet=True)
# Out:
# 'neiro_06-23.csv'

# %%
# Создадаем переменную data, в которую с помощью функции pd.read_csv() загружаем данные из файла
# data = pd.read_csv('view?usp=sharing')
data = pd.read_csv('neiro_06-23.csv', sep = ';', on_bad_lines='skip', engine='python' )
# Вывод датасета на экран
data
# Out:
#              ДокументПрохождениеМедосмотра  \
# 0     8ad4616c-0b5b-11ee-8133-0cc47aab8067
# 1     bd94cd34-0b62-11ee-8133-0cc47aab8067
# 2     02a95076-0b63-11ee-8133-0cc47aab8067
# 3     cb61c14c-0b6d-11ee-8133-0cc47aab8067
# 4     1ab6ecd0-0b64-11ee-8133-0cc47aab8067
# ...                                    ...
# 1036  346a9c13-0e65-11ee-8133-0cc47aab8067
# 1037  0dc1a36a-0e78-11ee-8133-0cc47aab8067
# 1038  43a376cb-0e53-11ee-8133-0cc47aab8067
# 1039  f2163f48-0e61-11ee-8133-0cc47aab8067
# 1040  98158ddc-f2d4-11ed-812e-0cc47aab8067
#
#                                     Клиент   КлиентДатаРождения КлиентПол  \
# 0     2264f308-b78c-11ea-80dd-0cc47aab8067  1980-08-29T00:00:00   Мужской
# 1     b1ebfc4c-a367-11ec-80ff-0cc47aab8067  1988-02-12T00:00:00   Мужской
# 2     28b3b8f4-c23c-11ec-8100-0cc47aab8067  1980-08-26T00:00:00   Мужской
# 3     300cb78c-da36-11eb-80f6-0cc47aab8067  1983-02-22T00:00:00   Мужской
# ...

# %%
# Создание копии датасета
data_backup = data.copy()
# Вывод на экран первых и последних пяти строк
data.head()
# Out:
#           ДокументПрохождениеМедосмотра                                Клиент  \
# 0  8ad4616c-0b5b-11ee-8133-0cc47aab8067  2264f308-b78c-11ea-80dd-0cc47aab8067
# 1  bd94cd34-0b62-11ee-8133-0cc47aab8067  b1ebfc4c-a367-11ec-80ff-0cc47aab8067
# 2  02a95076-0b63-11ee-8133-0cc47aab8067  28b3b8f4-c23c-11ec-8100-0cc47aab8067
# 3  cb61c14c-0b6d-11ee-8133-0cc47aab8067  300cb78c-da36-11eb-80f6-0cc47aab8067
# 4  1ab6ecd0-0b64-11ee-8133-0cc47aab8067  5755a71d-db14-11ec-8100-0cc47aab8067
#
#     КлиентДатаРождения КлиентПол КлиентПолПредставление  \
# 0  1980-08-29T00:00:00   Мужской                Мужской
# 1  1988-02-12T00:00:00   Мужской                Мужской
# 2  1980-08-26T00:00:00   Мужской                Мужской
# 3  1983-02-22T00:00:00   Мужской                Мужской
# 4  1995-01-24T00:00:00   Мужской                Мужской
#
#   ДатаЗавершенияМедосмотра  ТипМедосмотра ТипМедосмотраПредставление  \
# 0      2023-04-06T00:00:00  Периодический              Периодический
# ...

# %%
data.tail()
# Out:
#              ДокументПрохождениеМедосмотра  \
# 1036  346a9c13-0e65-11ee-8133-0cc47aab8067
# 1037  0dc1a36a-0e78-11ee-8133-0cc47aab8067
# 1038  43a376cb-0e53-11ee-8133-0cc47aab8067
# 1039  f2163f48-0e61-11ee-8133-0cc47aab8067
# 1040  98158ddc-f2d4-11ed-812e-0cc47aab8067
#
#                                     Клиент   КлиентДатаРождения КлиентПол  \
# 1036  d942cc21-e669-11ec-8102-0cc47aab8067  1975-02-18T00:00:00   Мужской
# 1037  c31ae865-e5bb-11ed-812b-0cc47aab8067  1971-06-04T00:00:00   Мужской
# 1038  71fb1a04-28f6-11e7-80d5-708bcd7f83cd  1978-12-12T00:00:00   Мужской
# 1039  c5c58eaf-cb1b-11ea-80e0-0cc47aab8067  1995-01-27T00:00:00   Женский
# 1040  ccee08b5-df73-11ed-812a-0cc47aab8067  1972-08-07T00:00:00   Мужской
#
#      КлиентПолПредставление ДатаЗавершенияМедосмотра  ТипМедосмотра  \
# 1036                Мужской      2023-06-19T00:00:00  Периодический
# 1037                Мужской      2023-06-19T00:00:00  Периодический
# ...

# %%
# Восстановление датасета
data = data_backup.copy()
data.head()
# Out:
#           ДокументПрохождениеМедосмотра                                Клиент  \
# 0  8ad4616c-0b5b-11ee-8133-0cc47aab8067  2264f308-b78c-11ea-80dd-0cc47aab8067
# 1  bd94cd34-0b62-11ee-8133-0cc47aab8067  b1ebfc4c-a367-11ec-80ff-0cc47aab8067
# 2  02a95076-0b63-11ee-8133-0cc47aab8067  28b3b8f4-c23c-11ec-8100-0cc47aab8067
# 3  cb61c14c-0b6d-11ee-8133-0cc47aab8067  300cb78c-da36-11eb-80f6-0cc47aab8067
# 4  1ab6ecd0-0b64-11ee-8133-0cc47aab8067  5755a71d-db14-11ec-8100-0cc47aab8067
#
#     КлиентДатаРождения КлиентПол КлиентПолПредставление  \
# 0  1980-08-29T00:00:00   Мужской                Мужской
# 1  1988-02-12T00:00:00   Мужской                Мужской
# 2  1980-08-26T00:00:00   Мужской                Мужской
# 3  1983-02-22T00:00:00   Мужской                Мужской
# 4  1995-01-24T00:00:00   Мужской                Мужской
#
#   ДатаЗавершенияМедосмотра  ТипМедосмотра ТипМедосмотраПредставление  \
# 0      2023-04-06T00:00:00  Периодический              Периодический
# ...

# %%
# Анализ датасета
data.shape
# Out:
# (1041, 190)

# %%
data.size
# Out:
# 197790

# %%
data.count
# Out:
# <bound method DataFrame.count of              ДокументПрохождениеМедосмотра  \
# 0     8ad4616c-0b5b-11ee-8133-0cc47aab8067
# 1     bd94cd34-0b62-11ee-8133-0cc47aab8067
# 2     02a95076-0b63-11ee-8133-0cc47aab8067
# 3     cb61c14c-0b6d-11ee-8133-0cc47aab8067
# 4     1ab6ecd0-0b64-11ee-8133-0cc47aab8067
# ...                                    ...
# 1036  346a9c13-0e65-11ee-8133-0cc47aab8067
# 1037  0dc1a36a-0e78-11ee-8133-0cc47aab8067
# 1038  43a376cb-0e53-11ee-8133-0cc47aab8067
# 1039  f2163f48-0e61-11ee-8133-0cc47aab8067
# 1040  98158ddc-f2d4-11ed-812e-0cc47aab8067
#
#                                     Клиент   КлиентДатаРождения КлиентПол  \
# 0     2264f308-b78c-11ea-80dd-0cc47aab8067  1980-08-29T00:00:00   Мужской
# 1     b1ebfc4c-a367-11ec-80ff-0cc47aab8067  1988-02-12T00:00:00   Мужской
# 2     28b3b8f4-c23c-11ec-8100-0cc47aab8067  1980-08-26T00:00:00   Мужской
# 3     300cb78c-da36-11eb-80f6-0cc47aab8067  1983-02-22T00:00:00   Мужской
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of              ДокументПрохождениеМедосмотра  \
# 0     8ad4616c-0b5b-11ee-8133-0cc47aab8067
# 1     bd94cd34-0b62-11ee-8133-0cc47aab8067
# 2     02a95076-0b63-11ee-8133-0cc47aab8067
# 3     cb61c14c-0b6d-11ee-8133-0cc47aab8067
# 4     1ab6ecd0-0b64-11ee-8133-0cc47aab8067
# ...                                    ...
# 1036  346a9c13-0e65-11ee-8133-0cc47aab8067
# 1037  0dc1a36a-0e78-11ee-8133-0cc47aab8067
# 1038  43a376cb-0e53-11ee-8133-0cc47aab8067
# 1039  f2163f48-0e61-11ee-8133-0cc47aab8067
# 1040  98158ddc-f2d4-11ed-812e-0cc47aab8067
#
#                                     Клиент   КлиентДатаРождения КлиентПол  \
# 0     2264f308-b78c-11ea-80dd-0cc47aab8067  1980-08-29T00:00:00   Мужской
# 1     b1ebfc4c-a367-11ec-80ff-0cc47aab8067  1988-02-12T00:00:00   Мужской
# 2     28b3b8f4-c23c-11ec-8100-0cc47aab8067  1980-08-26T00:00:00   Мужской
# 3     300cb78c-da36-11eb-80f6-0cc47aab8067  1983-02-22T00:00:00   Мужской
# ...

# %%
# Количетво пустых ячеек
data.isna().sum()
# Out:
# ДокументПрохождениеМедосмотра                 0
# Клиент                                        0
# КлиентДатаРождения                            0
# КлиентПол                                     0
# КлиентПолПредставление                        0
#                                            ...
# Хирургия2_ДатаПриема                       1040
# Хирургия2_МКБ101                           1040
# Хирургия2_ДиагнозПредставление1            1040
# Хирургия2_Диагноз_Значение                 1040
# Хирургия2_Диагноз_ЗначениеПредставление    1040
# Length: 190, dtype: int64

# %%
# Доля пропусков от общего количества элементов
data.isna().sum() / data.shape[0]
# Out:
# ДокументПрохождениеМедосмотра              0.000000
# Клиент                                     0.000000
# КлиентДатаРождения                         0.000000
# КлиентПол                                  0.000000
# КлиентПолПредставление                     0.000000
#                                              ...
# Хирургия2_ДатаПриема                       0.999039
# Хирургия2_МКБ101                           0.999039
# Хирургия2_ДиагнозПредставление1            0.999039
# Хирургия2_Диагноз_Значение                 0.999039
# Хирургия2_Диагноз_ЗначениеПредставление    0.999039
# Length: 190, dtype: float64

# %%
# Общее количество пропусков
data.isna().sum().sum()
# Out:
# 136994

# %% [markdown]
# # Подготовка данных

# %%
# Удаление столбцов, в которых все значения являются пустыми
data_new_colums = data.dropna(axis=1, how='all')

# Удаление строк, в которых все значения являются пустыми
data_new = data_new_colums.dropna(axis=0, how='all')

# %%
# Размер нового датасета
data_new.shape
# Количество строк НЕ изменилось
# Out:
# (1041, 190)

# %%
# Получение сведений о данных
data_new['ЗаключениеМК'].value_counts()
# Out:
# Годен                               233
# ГоденСКоррекциейЗрения               11
# ВременноНегоден                       3
# ГоденБезРаботНаВысотах                1
# НуждаетсяВДообследованииИЛечении      1
# Name: ЗаключениеМК, dtype: int64

# %% [markdown]
# Вывод: Создается ощущение, что это очень маленький и несбалансированный датасет

# %%
data_new['ЗаключениеМКПредставление'].value_counts()
# Out:
# Годен к работе в указанных условиях                           233
# Годен к работе в указанных условиях (с коррекцией зрения)      11
# Временно не годен                                               3
# Годен к работе в указанных условиях (без работ на высотах)      1
# Нуждается в дообследовании и лечении                            1
# Name: ЗаключениеМКПредставление, dtype: int64

# %%
data_new['Заключение'].value_counts()
# Out:
# Годен к работе в указанных условиях                                       233
# Годен к работе в указанных условиях (с коррекцией зрения)                   8
# Временно не годен                                                           3
# Годен к работе в указанных условиях (с коррекцией зрения) кроме п.6.1.      3
# Годен к работе в указанных условиях (без работ на высотах)                  1
# Нуждается в дообследовании и лечении                                        1
# Name: Заключение, dtype: int64
