# %% [markdown]
# <a href="https://colab.research.google.com/github/Untick/InspectrumClinic_RS_gr2/blob/Denisenko-Sergey-folder/%D0%A1%D1%82%D0%B0%D0%B6%D0%B8%D1%80%D0%BE%D0%B2%D0%BA%D0%B01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gdown
gdown.download('https://storage.yandexcloud.net/terratraineeship/23_InspectrumClinic_RS/datasets/%D0%B4%D0%B0%D1%82%D0%B0%D1%81%D0%B5%D1%82%20%D0%BF%D1%80%D0%BE%D1%84%D0%BF%D0%B0%D1%82%D0%BE%D0%BB%D0%BE%D0%B3%20%D1%87%D0%B0%D1%81%D1%82%D1%8C.xlsx')
# Out:
# Downloading...
# From: https://storage.yandexcloud.net/terratraineeship/23_InspectrumClinic_RS/datasets/%D0%B4%D0%B0%D1%82%D0%B0%D1%81%D0%B5%D1%82%20%D0%BF%D1%80%D0%BE%D1%84%D0%BF%D0%B0%D1%82%D0%BE%D0%BB%D0%BE%D0%B3%20%D1%87%D0%B0%D1%81%D1%82%D1%8C.xlsx
# To: /content/%D0%B4%D0%B0%D1%82%D0%B0%D1%81%D0%B5%D1%82%20%D0%BF%D1%80%D0%BE%D1%84%D0%BF%D0%B0%D1%82%D0%BE%D0%BB%D0%BE%D0%B3%20%D1%87%D0%B0%D1%81%D1%82%D1%8C.xlsx
# 100%|██████████| 32.4M/32.4M [00:02<00:00, 14.9MB/s]
# '%D0%B4%D0%B0%D1%82%D0%B0%D1%81%D0%B5%D1%82%20%D0%BF%D1%80%D0%BE%D1%84%D0%BF%D0%B0%D1%82%D0%BE%D0%BB%D0%BE%D0%B3%20%D1%87%D0%B0%D1%81%D1%82%D1%8C.xlsx'

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel('%D0%B4%D0%B0%D1%82%D0%B0%D1%81%D0%B5%D1%82%20%D0%BF%D1%80%D0%BE%D1%84%D0%BF%D0%B0%D1%82%D0%BE%D0%BB%D0%BE%D0%B3%20%D1%87%D0%B0%D1%81%D1%82%D1%8C.xlsx')

# %%
data
# Out:
#              ДокументПрохождениеМедосмотра  \
# 0     7f41ca7e-7dac-11ec-80fc-0cc47aab8067
# 1     2ee1f9ac-83dd-11ec-80fc-0cc47aab8067
# 2     9cbb191e-8e24-11ec-80fe-0cc47aab8067
# 3     b8a33910-8eec-11ec-80fe-0cc47aab8067
# 4     0bb0d181-938c-11ec-80fe-0cc47aab8067
# ...                                    ...
# 1977  137af572-70a5-11ed-8109-0cc47aab8067
# 1978  26310d7e-70a5-11ed-8109-0cc47aab8067
# 1979  b2602553-705c-11ed-8109-0cc47aab8067
# 1980  d0358b83-7065-11ed-8109-0cc47aab8067
# 1981  a15e278b-71f5-11ed-810a-0cc47aab8067
#
#                                     Клиент КлиентДатаРождения КлиентПол  \
# 0     c91e3407-b81f-11e9-80cf-0cc47aab8067         1976-10-24   Женский
# 1     1a1a5fea-8b7f-11eb-80e8-0cc47aab8067         1987-11-18   Мужской
# 2     7fe324e0-fa51-11eb-80f6-0cc47aab8067         1985-09-08   Мужской
# 3     98f9d761-8d65-11ec-80fe-0cc47aab8067         1988-04-25   Мужской
# 4     009aac7d-7bcf-11eb-80e8-0cc47aab8067         1984-04-17   Мужской
# ...

# %%
# Количество строк и столбцов 
data.shape
# Out:
# (1982, 4587)

# %%
# количество элементов в каждом столбце (не пустых)
data.count()
# Out:
# ДокументПрохождениеМедосмотра                                             1982
# Клиент                                                                    1982
# КлиентДатаРождения                                                        1982
# КлиентПол                                                                 1982
# КлиентПолПредставление                                                    1982
#                                                                           ...
# Стоматология2_ВП2_ЗначениеПредставление                                      1
# Терапия2_ЗаключениеФОГК_Значение                                             1
# Терапия2_ЗаключениеФОГК_ЗначениеПредставление                                1
# Офтальмология1_ДвигательныйАппаратГлазДополнение_Значение                    1
# Офтальмология1_ДвигательныйАппаратГлазДополнение_ЗначениеПредставление       1
# Length: 4587, dtype: int64

# %%
# Информация о датафрейме
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1982 entries, 0 to 1981
# Columns: 4587 entries, ДокументПрохождениеМедосмотра to Офтальмология1_ДвигательныйАппаратГлазДополнение_ЗначениеПредставление
# dtypes: bool(1), datetime64[ns](43), float64(1253), object(3290)
# memory usage: 69.3+ MB

# %%
# Количество пропусков в каждом столбце
data.isna().sum()
# Out:
# ДокументПрохождениеМедосмотра                                                0
# Клиент                                                                       0
# КлиентДатаРождения                                                           0
# КлиентПол                                                                    0
# КлиентПолПредставление                                                       0
#                                                                           ...
# Стоматология2_ВП2_ЗначениеПредставление                                   1981
# Терапия2_ЗаключениеФОГК_Значение                                          1981
# Терапия2_ЗаключениеФОГК_ЗначениеПредставление                             1981
# Офтальмология1_ДвигательныйАппаратГлазДополнение_Значение                 1981
# Офтальмология1_ДвигательныйАппаратГлазДополнение_ЗначениеПредставление    1981
# Length: 4587, dtype: int64

# %%
# доля пропусков от общего количества элементов
data.isna().sum() / data.shape[0]
# Out:
# ДокументПрохождениеМедосмотра                                             0.000000
# Клиент                                                                    0.000000
# КлиентДатаРождения                                                        0.000000
# КлиентПол                                                                 0.000000
# КлиентПолПредставление                                                    0.000000
#                                                                             ...
# Стоматология2_ВП2_ЗначениеПредставление                                   0.999495
# Терапия2_ЗаключениеФОГК_Значение                                          0.999495
# Терапия2_ЗаключениеФОГК_ЗначениеПредставление                             0.999495
# Офтальмология1_ДвигательныйАппаратГлазДополнение_Значение                 0.999495
# Офтальмология1_ДвигательныйАппаратГлазДополнение_ЗначениеПредставление    0.999495
# Length: 4587, dtype: float64

# %%
data_backup = data.copy()
mask = data.count() < 3
data.drop(data.columns[mask], axis=1, inplace=True)
print(data.shape)
print(data.isna().sum())
# Out:
# (1982, 2764)
# ДокументПрохождениеМедосмотра                                                           0
# Клиент                                                                                  0
# КлиентДатаРождения                                                                      0
# КлиентПол                                                                               0
# КлиентПолПредставление                                                                  0
#                                                                                      ...
# Психиатрия2_ДанныхЗаНаркологическуюПатологиюНаМоментОсмотра_ЗначениеПредставление    1960
# ЛабораторныеИсследования1_Дополнительно_Значение                                     1975
# ЛабораторныеИсследования1_Дополнительно_ЗначениеПредставление                        1975
# Терапия1_ЗаключениеФОГК_Значение                                                     1979
# ...

# %%
data.isna().sum() / data.shape[0]
# Out:
# ДокументПрохождениеМедосмотра                                                        0.000000
# Клиент                                                                               0.000000
# КлиентДатаРождения                                                                   0.000000
# КлиентПол                                                                            0.000000
# КлиентПолПредставление                                                               0.000000
#                                                                                        ...
# Психиатрия2_ДанныхЗаНаркологическуюПатологиюНаМоментОсмотра_ЗначениеПредставление    0.988900
# ЛабораторныеИсследования1_Дополнительно_Значение                                     0.996468
# ЛабораторныеИсследования1_Дополнительно_ЗначениеПредставление                        0.996468
# Терапия1_ЗаключениеФОГК_Значение                                                     0.998486
# ...

# %%
data.describe()
# Out:
#        ПсихиатрияНаркология1_Профессиональное1  \
# count                                   1510.0
# mean                                       0.0
# std                                        0.0
# min                                        0.0
# 25%                                        0.0
# 50%                                        0.0
# 75%                                        0.0
# max                                        0.0
#
#        ПсихиатрияНаркология1_Чистая_Значение  \
# count                                    3.0
# mean                                     1.0
# std                                      0.0
# min                                      1.0
# 25%                                      1.0
# 50%                                      1.0
# 75%                                      1.0
# max                                      1.0
#
#        ПсихиатрияНаркология1_СоСледамиВВИнъекций_Значение  \
# count                                                3.0
# ...

# %%
data.describe(include=['O'])
# Out:
#                ДокументПрохождениеМедосмотра  \
# count                                   1982
# unique                                  1915
# top     e334cb0e-55a6-11ed-8108-0cc47aab8067
# freq                                       2
#
#                                       Клиент КлиентПол КлиентПолПредставление  \
# count                                   1982      1982                   1982
# unique                                  1911         2                      2
# top     116fe6a1-455f-11ed-8107-0cc47aab8067   Мужской                Мужской
# freq                                       3      1451                   1451
#
#         ТипМедосмотра ТипМедосмотраПредставление  \
# count            1982                       1982
# unique              2                          2
# top     Периодический              Периодический
# freq             1981                       1981
#
#                                   Контрагент         Цех Профессия  \
# ...

# %%
data.corr()
# Out:
# <ipython-input-48-c44ded798807>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                                                     ПсихОсвидетельствование  \
# ПсихОсвидетельствование                                            1.000000
# ПсихиатрияНаркология1_Профессиональное1                                 NaN
# ПсихиатрияНаркология1_Чистая_Значение                                   NaN
# ПсихиатрияНаркология1_СоСледамиВВИнъекций_Значение                      NaN
# ПсихиатрияНаркология1_Контактен_Значение                           0.612372
# ...                                                                     ...
# ТерапевтНеИсп1_ТемператураТелаТерапевт_Значение                         NaN
# ТерапевтНеИсп1_ТемператураТелаТерапевт_Значение...                      NaN
# ...

# %%
data = data_backup.copy()
data.corr()
# Out:
# <ipython-input-50-33c0c5972bc7>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                                                     ПсихОсвидетельствование  \
# ПсихОсвидетельствование                                            1.000000
# ПсихиатрияНаркология1_Профессиональное1                                 NaN
# ПсихиатрияНаркология1_Чистая_Значение                                   NaN
# ПсихиатрияНаркология1_СоСледамиВВИнъекций_Значение                      NaN
# ПсихиатрияНаркология1_Контактен_Значение                           0.612372
# ...                                                                     ...
# ТерапевтНеИсп1_ТемператураТелаТерапевт_Значение                         NaN
# ТерапевтНеИсп1_ТемператураТелаТерапевт_Значение...                      NaN
# ...

# %%
mask = data.dtypes == 'float64'
data.loc[:, data.columns[mask]].corr()
# Out:
#                                                     ПсихиатрияНаркология1_Профессиональное1  \
# ПсихиатрияНаркология1_Профессиональное1                                                 NaN
# ПсихиатрияНаркология1_Чистая_Значение                                                   NaN
# ПсихиатрияНаркология1_СоСледамиВВИнъекций_Значение                                      NaN
# ПсихиатрияНаркология1_Контактен_Значение                                                NaN
# ПсихиатрияНаркология1_НеКонтактен_Значение                                              NaN
# ...                                                                                     ...
# ТерапевтНеИсп1_ТемператураТелаТерапевт_Значение                                         NaN
# ТерапевтНеИсп1_ТемператураТелаТерапевт_Значение...                                      NaN
# ТерапевтНеИсп1_ИМТ_Значение                                                             NaN
# ...
